# %% [markdown]
# <p style="background-color:orange; padding:15px;"> <b>Write File: </b>Exceptions File</p>

# %%
# %%writefile exception.py

import sys

def format_error_message(error, error_detail: sys):
    """
    Formats error message with details like file name and line number where the error occurred.
    
    :param error: Exception object
    :param error_detail: sys.exc_info() for accessing error details
    :return: Formatted error message as a string
    """
    _, _, exc_tb = error_detail.exc_info()

    file_name = exc_tb.tb_frame.f_code.co_filename
    line_number = exc_tb.tb_lineno

    # ANSI escape codes for colors
    color_red = "\033[91m"
    color_green = "\033[92m"
    color_end = "\033[0m"  # Reset color to default

    error_message = "{color_red}Error occurred in Python script '{0}', line {1}: {2}{color_end}".format(
        file_name, line_number, str(error), color_red=color_red, color_end=color_end
    )

    return error_message

class CustomException(Exception):

    def __init__(self, error_message, error_detail: sys):
        """
        :param error_message: Error message in string format
        :param error_detail: sys.exc_info() for accessing error details
        """
        super().__init__(error_message)

        self.error_message = format_error_message(
            error_message, error_detail=error_detail
        )

    def __str__(self):
        """
        Overrides the string representation of the exception.
        
        :return: Formatted error message
        """
        return self.error_message
# Out:
# Overwriting exception.py

# %% [markdown]
# <p style="background-color:orange; padding:15px;"> <b>Write File: </b>Logger File</p>

# %%
# %%writefile logger.py

import os
import logging
from datetime import datetime
import webbrowser


LOG_DIR = os.path.join(os.getcwd(), "logs")
os.makedirs(LOG_DIR, exist_ok=True)

LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
LOG_FILE_PATH = os.path.join(LOG_DIR, LOG_FILE)

logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[%(asctime)s] %(levelname)s [%(module)s:%(lineno)d] - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    level=logging.INFO
)
def open_log():
    webbrowser.open(LOG_FILE_PATH)
# Out:
# Overwriting logger.py

# %% [markdown]
# <p style="background-color: #153E7E; padding:15px;"> <b></b> Import Modules</p>

# %%
import os
import pprint

from tqdm import tqdm
from dotenv import load_dotenv

from langchain.chat_models import ChatOpenAI
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain import PromptTemplate
from langchain_core.prompts import PromptTemplate, load_prompt
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers.json import SimpleJsonOutputParser

# %%
from logger import logging
from exception import CustomException

# %%
import warnings
warnings.filterwarnings("ignore")

load_dotenv()
# Out:
# True

# %%
# %%writefile .env
#
# # For "gemma 7b"
# NVIDIA_API_KEY = "<Insert Key>"
#
# # For "meta/llama3-8b-instruct"
#
# OPENAI_API_KEY= "<Insert Key>"
# GOOGLE_API_KEY = "<Insert Key>"
# Out:
# Overwriting .env

# %%
import os 
from dotenv import load_dotenv

load_dotenv()
openai_api_key = os.getenv("NVIDIA_API_KEY")
if not openai_api_key:
    raise ValueError("NVIDIA_API_KEY not found in environment variables.")

# %%
# pip install -U langchain-nvidia-ai-endpoints

# %%
import pandas as pd

transcript_df = pd.read_excel("transcript_shuffled.xlsx")
transcript_df
# Out:
#      Unnamed: 0   ID                                         Transcript  \
# 0           245  653  "This is Nurse Thompson at Lakeside Hospital. ...
# 1           469   71  "My friend has a known allergy to soy and acci...
# 2           317  213  "My wife just stopped seizing, but she's confu...
# 3            20   17  "A man at the restaurant just fell and isn't r...
# 4           318  378  I slipped on the ice and my leg buckled. I thi...
# ..          ...  ...                                                ...
# 795         633  171  My wife is unconscious! She's been complaining...
# 796         766  759  Hello, I need an ambulance. My wife, she's bee...
# 797         205  345               "It's not a big deal, I'll be fine."
# 798         305  681  "This is Nurse Miller from Willow Creek Hospit...
# 799         206   73  "My coworker is allergic to tree nuts and acci...
#
#                            Category  DX code
# 0    Level 2 interfacility transfer  Dx01123
# 1                       Anaphylaxis   Dx1010
# 2                       Fitting now   Dx0103
# 3                    Cardiac Arrest    Dx010
# 4          Potential Broken Arm/Leg     Dx02
# ..                              ...      ...
# 795                 Unconsciousness   Dx0107
# 796                         Unknown      UNK
# 797                    Refused care   Dx0321
# 798  Level 2 interfacility transfer  Dx01123
# 799                     Anaphylaxis   Dx1010
#
# [800 rows x 5 columns]

# %%
# from langchain_nvidia_ai_endpoints import ChatNVIDIA

# llm = ChatNVIDIA(model="google/gemma-7b") #"mixtral_8x7b")
# result = llm.invoke("Write a ballad about LangChain.")
# print(result.content)

# %%
CALL_PROMPT_FILE_NAME: str = "CALL_PROMPT.yaml"
CALL_SUMMARIZATION_PROMPT_FILENAME: str = "SUMMARIZATION_PROMPT.yaml"
DEFAULT_MODEL_NAME: str = "gpt-4-turbo"
# "google/gemma-7b"
#"gpt-4-turbo"

# %%
CALL_PROMPT = """ 

Role: As a Language Model Assistant in an ambulance healthcare setting, your role is to assist with predicting call categories by accurately analyzing patient call transcripts to expedite the triage process.
    Vision:  You are extracting key information based on the Patient transcripts.
    Mission: Provide concise, relevant, and clear summaries of patient issues based on the patient transcripts, ensuring that they are classified appropriately and directed to the correct team for immediate attention. 

    While answering, for Severity Levels, you can choose a severity based on the context below:

    Low Severity:
        - Genito-Urinary conditions
        - Dental problem
        - Failed contraception
        - Palliative Care
        - Suicidal
    Medium Severity:
        - Level 2 interfacility transfer
        - Acute coronary syndrome
        - Refused Ambulance disposition
        - Potential Broken Arm/Leg
        - Covid symptoms with respiratory distress
    High Severity:
        - Major Blood Loss
        - Fitting now
        - Unconsciousness
        - Anaphylaxis
        - Cardiac arrest
        
    Provide the output in JSON format with the following keys:
        - Issue: (string) - Brief description of the patient's concern.
        - Issue Summary: (string, less than 20 words) - Concise overview of the problem.
        - Severity: ( Low , Medium , High ) - Urgency of the patient's situation.
        - Clinician to Contact: (general, support, technical) - If the transcript contains 3 or more “Not Sure” Keywords or “I don’t know” In it then output “Clinician to Contact Patient”
    
    Note: Before answering a question, ensure that the provided transcript is related to a reporting an issue or a similar scenario and not anything else apart from this. If not, then output 'Invalid' for all keys.

    Transcript:
    {Transcript}

"""

SUMMARIZATION_PROMPT = \
"""Please summarize the following text, capturing the key points and main concerns expressed in less than 10 words:

{Transcript}

Make sure to include relevant details, such as symptoms, background information, current situations, and any specific requests or questions posed.
"""

# %%
# os.environ['GOOGLE_API_KEY'] = ""
# os.environ['OPENAI_API_KEY'] = ""
# os.environ['NVIDIA_API_KEY'] = ""

# %%
def save_prompt(template: str, input_variables: list, file_name: str):
    """
    Save a prompt template to a file and then load it back.

    Args:
        template (str): The template string for the prompt.
        input_variables (list): List of input variables used in the template.
        file_name (str): The name of the file to save the prompt template to.

    """
    prompt = PromptTemplate(
        template=template,
        input_variables=input_variables,
    )

    prompt.save(file_name)
    print(f"Prompt template saved to {file_name}")
    
    return 0

# %%
save_prompt(CALL_PROMPT, [], CALL_PROMPT_FILE_NAME)
save_prompt(SUMMARIZATION_PROMPT, [], CALL_SUMMARIZATION_PROMPT_FILENAME)
# Out:
# Prompt template saved to CALL_PROMPT.yaml
# Prompt template saved to SUMMARIZATION_PROMPT.yaml
# 0

# %%
PROCESSED_DATA = []
RAW_SUMMARY_OUTPUT = []
RAW_CLASSIFIER_OUTPUT = []

# %%
class CallDataProcessor:

    def __init__(self, model_name, summarization_prompt_path, classifier_prompt_path):
        self.summarization_prompt = load_prompt(summarization_prompt_path)
        self.classifier_prompt = load_prompt(classifier_prompt_path)
        self.model_name = model_name 

    def process_input(self, input_data):
        try:

            llm = ChatOpenAI(model=self.model_name, temperature=0)
            llm_json = ChatOpenAI(model=self.model_name, temperature=0, model_kwargs={'response_format': {"type": "json_object"}})

            # llm = ChatNVIDIA(model=self.model_name, temperature=0) #Uncomment ChatNVIDIA and Comment ChatOPENAI, if using with NVDIA API
            # llm_json = ChatNVIDIA(model=self.model_name, temperature=0, model_kwargs={'response_format': {"type": "json_object"}})
            
            # Create the classifier and summary chains
            classifier_chain = self.classifier_prompt | llm_json | SimpleJsonOutputParser()
            classifier_result = classifier_chain.invoke(input_data)
            
            summary_chain = self.summarization_prompt | llm
            summary_result = summary_chain.invoke(input_data).content
            
            logging.info(f"Transcript: {input_data}|\
                        {self.model_name} - Summary Output: {summary_result}|\
                        {self.model_name} - Classifier Output: {classifier_result}\n")
           
            
            # Structure the results
            result = {
                "Transcript": input_data,
                f"{self.model_name} - Summary": summary_result,
                f"{self.model_name} - Issue": classifier_result['Issue'],
                f"{self.model_name} - Issue Summary": classifier_result['Issue Summary'],
                f"{self.model_name} - Severity": classifier_result['Severity'],
                f"{self.model_name} - Clinician to Contact": classifier_result['Clinician to Contact']
            }
        
            
            RAW_SUMMARY_OUTPUT.append(summary_result)
            RAW_CLASSIFIER_OUTPUT.append(classifier_result)
            
            PROCESSED_DATA.append(result) 
        
            return result      
    
        except Exception as e:
            print(f"An error occurred: {e}")
            return None

# %%
classifier_prompt_path= CALL_PROMPT_FILE_NAME
summarization_prompt_path = CALL_SUMMARIZATION_PROMPT_FILENAME

# processor = CallDataProcessor(DEFAULT_MODEL_NAME, summarization_prompt_path, classifier_prompt_path)

# %%
# input = "Please hurry, she's unconscious on the floor! I tried checking her pulse, but there's nothing. We've already called 911, but she needs help now! I think she might have hit her head when she fell. Is there anything we can do while we wait for the ambulance?"

# %%
# llm_response = processor.process_input(input)
# llm_response

# %%
DEFAULT_MODEL_NAME: str = "google/gemma-7b"
# "meta/llama3-8b-instruct"
# "meta/llama3-70b"
# "meta/llama3-70b-instruct" 
# "meta/llama3-70b"
#"mixtral_8x7b"

# "google/gemma-7b"

# %%
NUM_RECORDS = 200

# Comment out the following line to use the whole dataset as input.
df=transcript_df[:NUM_RECORDS]


df.reset_index(inplace=True)
df
# Out:
#      index  Unnamed: 0   ID  \
# 0        0         245  653
# 1        1         469   71
# 2        2         317  213
# 3        3          20   17
# 4        4         318  378
# ..     ...         ...  ...
# 195    195         513  135
# 196    196         493  151
# 197    197          38  137
# 198    198         255  448
# 199    199         746   37
#
#                                             Transcript  \
# 0    "This is Nurse Thompson at Lakeside Hospital. ...
# 1    "My friend has a known allergy to soy and acci...
# 2    "My wife just stopped seizing, but she's confu...
# 3    "A man at the restaurant just fell and isn't r...
# 4    I slipped on the ice and my leg buckled. I thi...
# ..                                                 ...
# 195  "My friend's dental implant fell out and is ca...
# 196  My husband just collapsed! He's not breathing ...
# 197  "My partner's dental filling came out and is c...
# 198  "My girlfriend's contraceptive shot wore off, ...
# 199  "My neighbor is on the ground, not breathing, ...
#
#                            Category  DX code
# 0    Level 2 interfacility transfer  Dx01123
# 1                       Anaphylaxis   Dx1010
# 2                       Fitting now   Dx0103
# 3                    Cardiac Arrest    Dx010
# 4          Potential Broken Arm/Leg     Dx02
# ..                              ...      ...
# 195                  Dental Problem    Dx019
# 196                 Unconsciousness   Dx0107
# 197                  Dental Problem    Dx019
# 198            Failed Contraception    Dx329
# 199                  Cardiac Arrest    Dx010
#
# [200 rows x 6 columns]

# %%
PROCESSED_DATA
PROCESSED_DATA = []
# Out:
# []

# %%
processor = CallDataProcessor(DEFAULT_MODEL_NAME, summarization_prompt_path, classifier_prompt_path)

for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing"):
    notes = row['Transcript']
    processor.process_input(notes)
# Out:
# Processing: 100%|██████████| 200/200 [12:39<00:00,  3.80s/it]

# %%
PROCESSED_DATA
# Out:
# [{'Transcript': '"This is Nurse Thompson at Lakeside Hospital. We have a patient, Mr. David Brown, in room 205, who requires an urgent transfer. He\'s exhibiting signs of a stroke."',
#   'gpt-4-turbo - Summary': 'Urgent transfer needed for stroke patient in room 205.',
#   'gpt-4-turbo - Issue': 'Urgent patient transfer required for potential stroke',
#   'gpt-4-turbo - Issue Summary': 'Patient showing stroke symptoms, needs urgent transfer.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My friend has a known allergy to soy and accidentally ingested some. Please send help fast!"',
#   'gpt-4-turbo - Summary': 'Friend ingested soy, has allergy, needs immediate help.',
#   'gpt-4-turbo - Issue': 'Accidental ingestion of allergen (soy)',
#   'gpt-4-turbo - Issue Summary': 'Friend ingested soy, has known allergy',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My wife just stopped seizing, but she\'s confused and doesn\'t remember anything. Is this normal?"',
#   'gpt-4-turbo - Summary': 'Post-seizure confusion; memory loss; seeks normalcy confirmation.',
#   'gpt-4-turbo - Issue': "Post-seizure confusion in patient's wife",
#   'gpt-4-turbo - Issue Summary': 'Wife experienced seizure, now confused and amnesic.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"A man at the restaurant just fell and isn\'t responding. There\'s no pulse. Please hurry!"',
#   'gpt-4-turbo - Summary': 'Man fell, unresponsive, no pulse at restaurant; needs urgent help.',
#   'gpt-4-turbo - Issue': 'Man unresponsive with no pulse at a restaurant',
#   'gpt-4-turbo - Issue Summary': 'Unresponsive man, no pulse, emergency required',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': 'I slipped on the ice and my leg buckled. I think I might have broken something.',
#   'gpt-4-turbo - Summary': 'Slipped on ice, leg injury, possible break.',
#   'gpt-4-turbo - Issue': 'Possible broken leg due to slipping on ice',
#   'gpt-4-turbo - Issue Summary': 'Patient suspects broken leg after slipping',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My daughter is making grunting noises during her seizure. Is this normal?"',
#   'gpt-4-turbo - Summary': 'Daughter grunts during seizure; parent questions normalcy.',
#   'gpt-4-turbo - Issue': 'Daughter experiencing seizure with grunting noises',
#   'gpt-4-turbo - Issue Summary': 'Seizure with abnormal vocalization in child',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I don\'t want to be alone in the hospital."',
#   'gpt-4-turbo - Summary': 'Person fears hospital solitude; seeks companionship.',
#   'gpt-4-turbo - Issue': 'Invalid',
#   'gpt-4-turbo - Issue Summary': 'Invalid',
#   'gpt-4-turbo - Severity': 'Invalid',
#   'gpt-4-turbo - Clinician to Contact': 'Invalid'},
#  {'Transcript': '"Hello... I need to talk to someone... I\'ve been in an accident... I\'m bleeding... please help..."',
#   'gpt-4-turbo - Summary': 'Accident victim bleeding, urgently needs help.',
#   'gpt-4-turbo - Issue': 'Patient reports being in an accident with bleeding',
#   'gpt-4-turbo - Issue Summary': 'Accident with bleeding',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My daughter has a history of asthma and is now experiencing chest pain and shortness of breath."',
#   'gpt-4-turbo - Summary': 'Daughter with asthma history has chest pain, breathing issues.',
#   'gpt-4-turbo - Issue': 'Daughter experiencing chest pain and shortness of breath with asthma history.',
#   'gpt-4-turbo - Issue Summary': 'Asthmatic child with chest pain and breathing difficulty.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My friend just had a seizure and doesn\'t remember anything. He\'s asking me where he is and what happened."',
#   'gpt-4-turbo - Summary': 'Friend had seizure, memory loss, disoriented.',
#   'gpt-4-turbo - Issue': 'Friend experienced a seizure and has memory loss',
#   'gpt-4-turbo - Issue Summary': 'Seizure with postictal confusion',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My sister is unconscious! She's been experiencing hallucinations and now she's unresponsive.",
#   'gpt-4-turbo - Summary': 'Sister unconscious, previously hallucinating.',
#   'gpt-4-turbo - Issue': 'Sister unconscious with prior hallucinations',
#   'gpt-4-turbo - Issue Summary': 'Unconsciousness following hallucinations',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My sister accidentally ate something with sesame and is struggling to breathe. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Sister ate sesame, can't breathe, needs ambulance.",
#   'gpt-4-turbo - Issue': 'Sister ingested sesame and is experiencing breathing difficulties.',
#   'gpt-4-turbo - Issue Summary': 'Sesame ingestion causing breathing issues.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My elderly parent has severe flank pain and blood in their urine. Send an ambulance immediately!"',
#   'gpt-4-turbo - Summary': 'Elderly parent with severe flank pain, needs ambulance now.',
#   'gpt-4-turbo - Issue': 'Elderly parent with severe flank pain and hematuria',
#   'gpt-4-turbo - Issue Summary': 'Severe flank pain and blood in urine',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I don\'t have anyone to look after my kids."',
#   'gpt-4-turbo - Summary': 'Parent lacks childcare support.',
#   'gpt-4-turbo - Issue': 'Invalid',
#   'gpt-4-turbo - Issue Summary': 'Invalid',
#   'gpt-4-turbo - Severity': 'Invalid',
#   'gpt-4-turbo - Clinician to Contact': 'Invalid'},
#  {'Transcript': '"My neighbor\'s child has a tooth abscess and is in unbearable pain. Please send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Child with tooth abscess in pain; needs ambulance.',
#   'gpt-4-turbo - Issue': "Neighbor's child with tooth abscess",
#   'gpt-4-turbo - Issue Summary': 'Child suffering from painful tooth abscess',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My wife fell and isn\'t breathing. There\'s no pulse. Please hurry with an ambulance!"',
#   'gpt-4-turbo - Summary': 'Wife fell, not breathing, no pulse; needs urgent ambulance.',
#   'gpt-4-turbo - Issue': 'Wife fell and is unresponsive with no pulse',
#   'gpt-4-turbo - Issue Summary': 'Unresponsive and pulseless after a fall',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"Hello, this is Nurse Davis from Central Hospital. We\'re requesting a transfer for Mr. Thomas White, room 211. He\'s experiencing severe dehydration and electrolyte imbalance."',
#   'gpt-4-turbo - Summary': 'Requesting transfer for severely dehydrated patient with electrolyte imbalance.',
#   'gpt-4-turbo - Issue': 'Severe dehydration and electrolyte imbalance',
#   'gpt-4-turbo - Issue Summary': 'Requesting transfer for dehydration and imbalance',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My father is having difficulty speaking and is feeling very weak."',
#   'gpt-4-turbo - Summary': 'Father experiencing speech difficulty and weakness.',
#   'gpt-4-turbo - Issue': 'Father experiencing difficulty speaking and feeling weak',
#   'gpt-4-turbo - Issue Summary': 'Difficulty speaking and weakness',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I'm calling for an ambulance. My daughter, she's been having a lot of pain in her stomach. It's getting worse. I don't know what's wrong. I don't know if it's appendicitis. I don't know what to do.",
#   'gpt-4-turbo - Summary': 'Daughter in severe stomach pain, fearing appendicitis, seeking ambulance.',
#   'gpt-4-turbo - Issue': 'Daughter experiencing severe stomach pain',
#   'gpt-4-turbo - Issue Summary': 'Severe stomach pain, worsening, cause uncertain.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': "Hello, I need an ambulance. I've been having this strange feeling in my arm. It's numb and tingly. I don't know what's wrong. I don't know if it's a stroke. I don't know what to do.",
#   'gpt-4-turbo - Summary': 'Person experiencing numb, tingly arm; fears stroke; seeks ambulance.',
#   'gpt-4-turbo - Issue': 'Numb and tingly arm with uncertainty about a stroke',
#   'gpt-4-turbo - Issue Summary': 'Patient reports numbness in arm, suspects stroke.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"I feel like I\'m a failure. I\'ve let everyone down. I... I just want to make it all go away."',
#   'gpt-4-turbo - Summary': 'Feeling of failure, desire to escape problems.',
#   'gpt-4-turbo - Issue': 'Expressing feelings of failure and despair',
#   'gpt-4-turbo - Issue Summary': 'Patient feels like a failure, wants to escape feelings',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My husband has a persistent cough and his breathing is getting worse. He's also experiencing chills and a headache. He has a history of lung cancer.",
#   'gpt-4-turbo - Summary': 'Husband with lung cancer has worsening cough, chills, headache.',
#   'gpt-4-turbo - Issue': 'Husband experiencing worsening respiratory symptoms with a history of lung cancer.',
#   'gpt-4-turbo - Issue Summary': 'Worsening cough, breathing issues, chills, headache.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My friend was stung by a bee and now her throat is closing up. We need medical assistance!"',
#   'gpt-4-turbo - Summary': 'Friend stung by bee, throat closing, needs medical help.',
#   'gpt-4-turbo - Issue': 'Friend experiencing anaphylactic reaction from bee sting',
#   'gpt-4-turbo - Issue Summary': 'Bee sting causing throat closure, needs urgent help',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I\'ve been struggling with this for so long and I feel like I\'m finally at my breaking point. I... I need someone to help me."',
#   'gpt-4-turbo - Summary': 'Struggling long-term, needs immediate help.',
#   'gpt-4-turbo - Issue': 'Patient expressing emotional distress and need for help',
#   'gpt-4-turbo - Issue Summary': 'Patient at breaking point, needs urgent help',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I was in a fight. I got stabbed, I\'m bleeding heavily. I need help now."',
#   'gpt-4-turbo - Summary': 'Stabbed, bleeding heavily, urgently needs help.',
#   'gpt-4-turbo - Issue': 'Patient reports being stabbed and experiencing heavy bleeding.',
#   'gpt-4-turbo - Issue Summary': 'Stabbed with major blood loss, needs urgent help.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"A person at the pool collapsed and isn\'t breathing. We need medical assistance immediately!"',
#   'gpt-4-turbo - Summary': 'Person collapsed at pool, needs immediate medical help, not breathing.',
#   'gpt-4-turbo - Issue': "Person collapsed and isn't breathing at the pool",
#   'gpt-4-turbo - Issue Summary': 'Individual collapsed, not breathing, requires urgent help',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My elderly parent is experiencing severe burning during urination and is unable to urinate. Send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Elderly parent, severe burning urination, unable to urinate, needs ambulance.',
#   'gpt-4-turbo - Issue': 'Severe burning during urination and inability to urinate in an elderly patient.',
#   'gpt-4-turbo - Issue Summary': 'Elderly patient with severe urinary discomfort.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My friend\'s contraceptive sponge didn\'t work, and she\'s worried about pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Friend's contraceptive failed, fears pregnancy, requests ambulance.",
#   'gpt-4-turbo - Issue': 'Failed contraception leading to pregnancy concerns',
#   'gpt-4-turbo - Issue Summary': 'Concerns over failed contraceptive sponge.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My friend collapsed during our run and isn\'t breathing. I\'m starting CPR, but we need help!"',
#   'gpt-4-turbo - Summary': 'Friend collapsed, not breathing, CPR started, need help.',
#   'gpt-4-turbo - Issue': "Friend collapsed and isn't breathing during a run.",
#   'gpt-4-turbo - Issue Summary': 'Friend collapsed, not breathing, CPR started.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My partner\'s contraceptive shot didn\'t work, and we\'re concerned about pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Concern over failed contraceptive shot, possible pregnancy, requests ambulance.',
#   'gpt-4-turbo - Issue': 'Failed contraception leading to pregnancy concerns',
#   'gpt-4-turbo - Issue Summary': 'Concerned about pregnancy due to failed contraception.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I\'m at [Address] and I\'m having suicidal thoughts. I... I don\'t know what to do anymore."',
#   'gpt-4-turbo - Summary': 'Person at [Address] experiencing suicidal thoughts, needs immediate help.',
#   'gpt-4-turbo - Issue': 'Patient experiencing suicidal thoughts',
#   'gpt-4-turbo - Issue Summary': 'Patient at [Address] reports suicidal ideation.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"My sibling has sudden and severe lower back pain and frequent urination. Send an ambulance urgently!"',
#   'gpt-4-turbo - Summary': 'Sudden severe back pain, frequent urination; needs ambulance urgently.',
#   'gpt-4-turbo - Issue': 'Severe lower back pain and frequent urination',
#   'gpt-4-turbo - Issue Summary': 'Sudden severe back pain with frequent urination.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I can take care of myself, I don\'t need your help."',
#   'gpt-4-turbo - Summary': 'Individual asserts independence, declines assistance.',
#   'gpt-4-turbo - Issue': 'Invalid',
#   'gpt-4-turbo - Issue Summary': 'Invalid',
#   'gpt-4-turbo - Severity': 'Invalid',
#   'gpt-4-turbo - Clinician to Contact': 'Invalid'},
#  {'Transcript': '"I\'m scared of hospitals, I don\'t want to go."',
#   'gpt-4-turbo - Summary': 'Person fears hospitals, avoids going.',
#   'gpt-4-turbo - Issue': 'Fear of hospitals',
#   'gpt-4-turbo - Issue Summary': 'Patient expresses fear of hospital visits.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I fractured my arm a few months ago and I think I've re-injured it. It's swollen again and I'm worried it's broken.",
#   'gpt-4-turbo - Summary': "Re-injured previously fractured arm, worried it's broken again.",
#   'gpt-4-turbo - Issue': 'Re-injured previously fractured arm',
#   'gpt-4-turbo - Issue Summary': 'Swollen arm, possible re-fracture',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My husband accidentally ate shellfish and is having trouble breathing. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Husband ate shellfish, can't breathe, needs ambulance.",
#   'gpt-4-turbo - Issue': 'Accidental shellfish ingestion leading to breathing difficulties',
#   'gpt-4-turbo - Issue Summary': 'Shellfish allergy causing breathing issues.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My friend is unconscious! He's been feeling very weak and now he's not moving.",
#   'gpt-4-turbo - Summary': 'Friend unconscious, feeling weak, now immobile.',
#   'gpt-4-turbo - Issue': 'Friend is unconscious and feeling very weak',
#   'gpt-4-turbo - Issue Summary': 'Unconsciousness with prior weakness',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I don\'t want to cause a scene."',
#   'gpt-4-turbo - Summary': 'Avoiding public disturbance; prefers discretion.',
#   'gpt-4-turbo - Issue': 'Invalid',
#   'gpt-4-turbo - Issue Summary': 'Invalid',
#   'gpt-4-turbo - Severity': 'Invalid',
#   'gpt-4-turbo - Clinician to Contact': 'Invalid'},
#  {'Transcript': '"My elderly neighbor collapsed and isn\'t responding. I think she\'s having a seizure!"',
#   'gpt-4-turbo - Summary': 'Elderly neighbor collapsed, unresponsive, possible seizure.',
#   'gpt-4-turbo - Issue': 'Elderly neighbor collapsed and unresponsive, possible seizure',
#   'gpt-4-turbo - Issue Summary': 'Elderly neighbor collapsed, possibly seizing, unresponsive.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My son is seizing and he bit his tongue! There\'s a lot of blood!"',
#   'gpt-4-turbo - Summary': 'Son seizing, tongue bitten, bleeding heavily.',
#   'gpt-4-turbo - Issue': 'Son experiencing seizures and tongue injury with significant bleeding.',
#   'gpt-4-turbo - Issue Summary': 'Seizures with tongue injury and major blood loss.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I can't seem to catch my breath. I have a fever, chills, and a sore throat. I also have a runny nose and a loss of taste. I have a history of heart disease and have had a recent heart attack.",
#   'gpt-4-turbo - Summary': 'Ill with respiratory symptoms, heart disease history, recent heart attack.',
#   'gpt-4-turbo - Issue': 'Patient experiencing respiratory distress with fever, chills, and other symptoms.',
#   'gpt-4-turbo - Issue Summary': 'Respiratory distress and fever in a patient with heart disease history.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My father\'s dentures got lodged in his throat and he\'s struggling to breathe. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Father's dentures stuck; can't breathe. Need ambulance immediately.",
#   'gpt-4-turbo - Issue': 'Dentures lodged in throat, difficulty breathing',
#   'gpt-4-turbo - Issue Summary': 'Father choking on dentures, needs urgent help',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My husband is experiencing pain in his left arm and shoulder, and he\'s feeling very anxious."',
#   'gpt-4-turbo - Summary': 'Husband has left arm, shoulder pain; feels anxious.',
#   'gpt-4-turbo - Issue': 'Husband experiencing pain in left arm and shoulder with anxiety.',
#   'gpt-4-turbo - Issue Summary': 'Left arm and shoulder pain with anxiety.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My neighbor\'s child\'s tooth got knocked out and is bleeding heavily. Send help fast!"',
#   'gpt-4-turbo - Summary': "Child's tooth knocked out, heavy bleeding, urgent help needed.",
#   'gpt-4-turbo - Issue': "Child's tooth knocked out with heavy bleeding",
#   'gpt-4-turbo - Issue Summary': 'Tooth loss and significant bleeding in child',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I'm feeling very short of breath and my oxygen levels are low. I have a fever and a persistent cough. I'm also experiencing abdominal pain and diarrhea. I have a history of autoimmune disease and am currently on immunosuppressants.",
#   'gpt-4-turbo - Summary': 'Ill, low oxygen, fever, cough, pain; on immunosuppressants.',
#   'gpt-4-turbo - Issue': 'Patient experiencing multiple severe symptoms',
#   'gpt-4-turbo - Issue Summary': 'Shortness of breath, low oxygen, fever, cough, abdominal pain, diarrhea',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"A man at the concert just dropped and isn\'t responding. I think he\'s in cardiac arrest!"',
#   'gpt-4-turbo - Summary': 'Man collapsed at concert, possibly in cardiac arrest.',
#   'gpt-4-turbo - Issue': 'Man unresponsive at a concert, suspected cardiac arrest.',
#   'gpt-4-turbo - Issue Summary': 'Unresponsive man, likely cardiac arrest at concert.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': 'My grandmother is out cold! She was eating dinner and suddenly slumped over.',
#   'gpt-4-turbo - Summary': 'Grandmother unconscious during dinner; needs immediate help.',
#   'gpt-4-turbo - Issue': 'Grandmother unconscious during dinner',
#   'gpt-4-turbo - Issue Summary': 'Elderly woman suddenly unconscious while eating.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"Good morning, this is Dr. Lee from Maplewood Hospital. I\'d like to request a transfer for Mr. Christopher Garcia, room 206. He\'s experiencing a possible acute kidney injury."',
#   'gpt-4-turbo - Summary': 'Dr. Lee requests transfer for patient with acute kidney injury.',
#   'gpt-4-turbo - Issue': 'Request for patient transfer due to possible acute kidney injury',
#   'gpt-4-turbo - Issue Summary': 'Transfer request for acute kidney injury',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My child\'s orthodontic retainer is stuck in their throat and they\'re choking. Send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Child choking on retainer, needs ambulance immediately.',
#   'gpt-4-turbo - Issue': 'Child choking on orthodontic retainer',
#   'gpt-4-turbo - Issue Summary': 'Child choking due to retainer in throat',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My daughter is having trouble breathing and her chest feels tight. She has a fever and a sore throat. She's also experiencing confusion and disorientation. She recently had close contact with someone who tested positive for COVID-19 and is immunocompromised.",
#   'gpt-4-turbo - Summary': 'Daughter with COVID-19 symptoms, immunocompromised, needs urgent care.',
#   'gpt-4-turbo - Issue': 'Daughter experiencing respiratory distress and other symptoms',
#   'gpt-4-turbo - Issue Summary': 'Trouble breathing, fever, sore throat, confusion, COVID-19 contact',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I need to return some library books, I can\'t leave the house."',
#   'gpt-4-turbo - Summary': 'Housebound; needs to return library books.',
#   'gpt-4-turbo - Issue': 'Invalid',
#   'gpt-4-turbo - Issue Summary': 'Invalid',
#   'gpt-4-turbo - Severity': 'Invalid',
#   'gpt-4-turbo - Clinician to Contact': 'Invalid'},
#  {'Transcript': '"Hello, I need an ambulance for my mother. She is in palliative care and is having trouble breathing."',
#   'gpt-4-turbo - Summary': 'Mother in palliative care, needs ambulance for breathing trouble.',
#   'gpt-4-turbo - Issue': 'Mother in palliative care with breathing difficulties',
#   'gpt-4-turbo - Issue Summary': 'Palliative care patient struggling to breathe',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My girlfriend\'s contraceptive method failed, and she\'s worried about pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Girlfriend's contraception failed, fears pregnancy, requests ambulance.",
#   'gpt-4-turbo - Issue': 'Failed contraception leading to pregnancy concerns.',
#   'gpt-4-turbo - Issue Summary': 'Concerns over failed contraception and potential pregnancy.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My neighbor is having a seizure and his body is jerking violently. What should I do?"',
#   'gpt-4-turbo - Summary': 'Neighbor seizing, jerking violently; seeking immediate help.',
#   'gpt-4-turbo - Issue': 'Neighbor experiencing a seizure',
#   'gpt-4-turbo - Issue Summary': 'Neighbor having a violent seizure',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My father is unresponsive! He's been feeling dizzy and now he's collapsed.",
#   'gpt-4-turbo - Summary': 'Father unresponsive, dizzy, collapsed.',
#   'gpt-4-turbo - Issue': 'Father unresponsive after feeling dizzy and collapsing',
#   'gpt-4-turbo - Issue Summary': 'Elderly male collapsed, currently unresponsive',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"The woman on the train is experiencing severe back pain and feels like she\'s going to faint."',
#   'gpt-4-turbo - Summary': 'Woman on train has severe back pain, feels faint.',
#   'gpt-4-turbo - Issue': 'Severe back pain and feeling faint',
#   'gpt-4-turbo - Issue Summary': 'Woman with severe back pain, feels faint',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My coworker\'s dental crown came loose and is causing severe pain and bleeding. Send help fast!"',
#   'gpt-4-turbo - Summary': "Coworker's loose dental crown causing pain, bleeding; needs urgent help.",
#   'gpt-4-turbo - Issue': 'Loose dental crown causing severe pain and bleeding',
#   'gpt-4-turbo - Issue Summary': 'Severe pain and bleeding from loose dental crown',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I\'m calling for my friend, he\'s having severe chest pain that radiates down his left arm, he\'s feeling nauseous and lightheaded."',
#   'gpt-4-turbo - Summary': 'Friend experiencing severe chest pain, nausea, needs immediate help.',
#   'gpt-4-turbo - Issue': 'Severe chest pain with radiation to left arm, nausea, and lightheadedness.',
#   'gpt-4-turbo - Issue Summary': 'Friend experiencing severe chest pain and related symptoms.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I\'ve been trying to cope, but I\'m at my limit. I need someone to help me before it\'s too late. Please, I need someone to talk to."',
#   'gpt-4-turbo - Summary': 'Person overwhelmed, urgently needs someone to talk to.',
#   'gpt-4-turbo - Issue': 'Patient expressing emotional distress and urgent need for support',
#   'gpt-4-turbo - Issue Summary': 'Patient at emotional limit, seeks urgent help',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My coworker\'s dental crown got dislodged and is stuck in their throat. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Coworker's dental crown stuck in throat; need ambulance immediately.",
#   'gpt-4-turbo - Issue': 'Dislodged dental crown stuck in throat',
#   'gpt-4-turbo - Issue Summary': 'Dental crown dislodged, causing choking hazard.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My daughter is having trouble breathing and her chest feels tight. She has a fever and a sore throat. She's also experiencing confusion and disorientation. She recently had close contact with someone who tested positive for COVID-19.",
#   'gpt-4-turbo - Summary': 'Daughter has COVID-19 symptoms, breathing difficulty, fever, confusion.',
#   'gpt-4-turbo - Issue': 'Daughter experiencing respiratory distress and other symptoms after COVID-19 exposure.',
#   'gpt-4-turbo - Issue Summary': 'Respiratory distress, fever, confusion post-COVID exposure.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My neighbor is allergic to latex and touched something, now he\'s fainting. Send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Neighbor touched latex, is fainting; needs ambulance.',
#   'gpt-4-turbo - Issue': 'Neighbor experiencing an allergic reaction with fainting',
#   'gpt-4-turbo - Issue Summary': 'Latex allergy causing fainting, needs urgent help',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My mother is on end-of-life care and she\'s experiencing severe nausea and vomiting and is refusing to take medication. Please send medical help."',
#   'gpt-4-turbo - Summary': 'Mother in end-of-life care, severe nausea, needs medical help.',
#   'gpt-4-turbo - Issue': 'Severe nausea and vomiting in palliative care patient',
#   'gpt-4-turbo - Issue Summary': 'End-of-life care patient with severe nausea, vomiting, refusing meds.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My brother had a head injury a few months ago, and now he\'s having a seizure. Is this related?"',
#   'gpt-4-turbo - Summary': "Brother's seizure possibly linked to recent head injury.",
#   'gpt-4-turbo - Issue': 'Brother experiencing a seizure following a past head injury',
#   'gpt-4-turbo - Issue Summary': 'Post-head injury seizure occurrence',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I'm calling for an ambulance. My daughter, she's been having a lot of nosebleeds. It's been going on for days. I don't know what's wrong. I don't know if it's serious. I don't know what to do.",
#   'gpt-4-turbo - Summary': "Daughter's persistent nosebleeds, parent worried, seeking ambulance.",
#   'gpt-4-turbo - Issue': 'Frequent nosebleeds in daughter',
#   'gpt-4-turbo - Issue Summary': 'Daughter experiencing persistent nosebleeds for days.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"My daughter has epilepsy, but she hasn\'t been taking her medication regularly. Now she\'s having a seizure. Is this because of the medication?"',
#   'gpt-4-turbo - Summary': "Daughter's irregular medication possibly causing seizures.",
#   'gpt-4-turbo - Issue': 'Epileptic seizure due to irregular medication intake',
#   'gpt-4-turbo - Issue Summary': 'Daughter experiencing seizure, possibly medication-related.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My baby is having a seizure and has a high fever! I\'m so worried!"',
#   'gpt-4-turbo - Summary': 'Baby with seizure and high fever; parent extremely worried.',
#   'gpt-4-turbo - Issue': 'Baby experiencing a seizure and high fever',
#   'gpt-4-turbo - Issue Summary': 'Seizure and high fever in infant',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My girlfriend\'s contraceptive implant failed, and she\'s concerned about pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Girlfriend's contraceptive failed, fears pregnancy, requests ambulance.",
#   'gpt-4-turbo - Issue': 'Failed contraceptive implant with pregnancy concern',
#   'gpt-4-turbo - Issue Summary': 'Concern over failed contraceptive implant.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My wife is unconscious! She's been having seizures and now she's not responding.",
#   'gpt-4-turbo - Summary': 'Wife unconscious, having seizures, unresponsive.',
#   'gpt-4-turbo - Issue': 'Wife unconscious with prior seizures',
#   'gpt-4-turbo - Issue Summary': 'Unconscious following seizures',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My mother is turning blue during her seizure! I\'m scared she\'s not getting enough oxygen!"',
#   'gpt-4-turbo - Summary': 'Mother turning blue during seizure; fears of oxygen deprivation.',
#   'gpt-4-turbo - Issue': 'Mother experiencing a seizure and turning blue',
#   'gpt-4-turbo - Issue Summary': 'Seizure with possible oxygen deprivation',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My colleague collapsed and isn\'t breathing. There\'s no pulse. We\'re starting CPR, but need an ambulance fast!"',
#   'gpt-4-turbo - Summary': 'Colleague collapsed, not breathing, no pulse, need ambulance for CPR.',
#   'gpt-4-turbo - Issue': 'Colleague collapsed and is unresponsive',
#   'gpt-4-turbo - Issue Summary': 'Colleague collapsed, not breathing, no pulse, CPR initiated',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"This is Nurse Thompson from Redwood Hospital. We have a patient, Mrs. Sarah Smith, in room 504, who needs an immediate transfer. She\'s experiencing a possible severe preeclampsia."',
#   'gpt-4-turbo - Summary': 'Patient needs urgent transfer for severe preeclampsia.',
#   'gpt-4-turbo - Issue': 'Patient requires immediate hospital transfer due to severe preeclampsia.',
#   'gpt-4-turbo - Issue Summary': 'Urgent transfer needed for severe preeclampsia.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I promised to help a friend move today, I can\'t cancel."',
#   'gpt-4-turbo - Summary': "Promised to help friend move; can't cancel.",
#   'gpt-4-turbo - Issue': 'Invalid',
#   'gpt-4-turbo - Issue Summary': 'Invalid',
#   'gpt-4-turbo - Severity': 'Invalid',
#   'gpt-4-turbo - Clinician to Contact': 'Invalid'},
#  {'Transcript': '"I can\'t afford an ambulance or the hospital bill."',
#   'gpt-4-turbo - Summary': 'No details provided; financial concern about medical costs.',
#   'gpt-4-turbo - Issue': 'Concern about affordability of ambulance and hospital services',
#   'gpt-4-turbo - Issue Summary': 'Patient worried about medical costs',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'support'},
#  {'Transcript': '"It\'s Dr. Davis from Maplewood Hospital. We need to transfer Ms. Jessica Jones, room 403. She\'s experiencing a possible metabolic encephalopathy."',
#   'gpt-4-turbo - Summary': 'Transfer Ms. Jones for possible metabolic encephalopathy.',
#   'gpt-4-turbo - Issue': 'Request for patient transfer due to possible metabolic encephalopathy',
#   'gpt-4-turbo - Issue Summary': 'Transfer needed for metabolic encephalopathy',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My mother is on end-of-life care and she\'s experiencing severe pain that her medication isn\'t controlling. Please send an ambulance right away."',
#   'gpt-4-turbo - Summary': 'Mother in severe pain, medication failing, needs ambulance immediately.',
#   'gpt-4-turbo - Issue': 'Severe pain in palliative care patient',
#   'gpt-4-turbo - Issue Summary': 'End-of-life care patient with uncontrolled severe pain.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I've broken this leg before and I think it might be broken again. The pain is similar to last time.",
#   'gpt-4-turbo - Summary': 'Leg possibly re-broken; pain similar to previous incident.',
#   'gpt-4-turbo - Issue': 'Suspected broken leg',
#   'gpt-4-turbo - Issue Summary': 'Patient suspects leg is broken, similar pain as before.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My mother is on end-of-life care and she\'s experiencing severe nausea and vomiting. Please send medical help."',
#   'gpt-4-turbo - Summary': 'Mother in end-of-life care, severe nausea; needs medical help.',
#   'gpt-4-turbo - Issue': 'Severe nausea and vomiting in palliative care patient',
#   'gpt-4-turbo - Issue Summary': 'End-of-life care patient with severe nausea, vomiting.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I'm calling for an ambulance. My daughter, she's been complaining of pain in her ear. She's crying. I don't know what's wrong. I don't know if it's an ear infection. I don't know what to do.",
#   'gpt-4-turbo - Summary': 'Daughter in pain, possibly ear infection, seeking medical help.',
#   'gpt-4-turbo - Issue': 'Daughter experiencing severe ear pain',
#   'gpt-4-turbo - Issue Summary': 'Child with severe ear pain, possibly infection.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"I\'m afraid of hospitals."',
#   'gpt-4-turbo - Summary': 'Fear of hospitals expressed; no details or context provided.',
#   'gpt-4-turbo - Issue': 'Fear of hospitals',
#   'gpt-4-turbo - Issue Summary': 'Patient expresses fear of hospitals.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My wife\'s contraceptive patch came off, and she\'s scared of pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Wife's contraceptive failure, fears pregnancy, requests ambulance.",
#   'gpt-4-turbo - Issue': 'Contraceptive patch came off',
#   'gpt-4-turbo - Issue Summary': 'Concern over potential pregnancy due to failed contraception.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"Dr. Rodriguez here from Cedarwood Hospital. I\'d like to request a Level 2 transfer for Mr. Daniel White, room 302. He\'s experiencing a possible acute pancreatitis."',
#   'gpt-4-turbo - Summary': 'Request Level 2 transfer for acute pancreatitis, patient White.',
#   'gpt-4-turbo - Issue': 'Request for Level 2 transfer due to possible acute pancreatitis',
#   'gpt-4-turbo - Issue Summary': 'Level 2 hospital transfer for acute pancreatitis.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I\'m bleeding... it\'s from my chest... I think I\'ve been shot... I\'m losing strength... please..."',
#   'gpt-4-turbo - Summary': 'Person shot, bleeding from chest, losing strength, seeks help.',
#   'gpt-4-turbo - Issue': 'Patient reports being shot in the chest with active bleeding.',
#   'gpt-4-turbo - Issue Summary': 'Gunshot wound to chest with active bleeding.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My mother is having a heart attack, she\'s 75 years old and has a history of high blood pressure and diabetes."',
#   'gpt-4-turbo - Summary': 'Elderly mother with heart attack, has hypertension and diabetes.',
#   'gpt-4-turbo - Issue': 'Mother experiencing a heart attack',
#   'gpt-4-turbo - Issue Summary': '75-year-old with heart attack, has hypertension and diabetes.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I need to talk to someone. I can\'t keep this bottled up anymore. I... I feel like I\'m going to explode."',
#   'gpt-4-turbo - Summary': 'Person feels overwhelmed, needs to talk.',
#   'gpt-4-turbo - Issue': 'Patient expressing emotional distress',
#   'gpt-4-turbo - Issue Summary': 'Patient feels overwhelmed and unable to cope',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I need help. My friend, he's been having a lot of pain in his abdomen. He's vomiting and has a fever. I don't know what's wrong. I don't know if it's appendicitis. I don't know what to do.",
#   'gpt-4-turbo - Summary': 'Friend with abdominal pain, vomiting, fever; possible appendicitis concern.',
#   'gpt-4-turbo - Issue': 'Friend experiencing severe abdominal pain, vomiting, and fever.',
#   'gpt-4-turbo - Issue Summary': 'Severe abdominal pain with vomiting and fever.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"My coworker\'s dental crown fell out and is causing intense pain and bleeding. Send help urgently!"',
#   'gpt-4-turbo - Summary': "Coworker's dental crown fell out; needs urgent help for pain.",
#   'gpt-4-turbo - Issue': 'Dental crown fell out causing pain and bleeding',
#   'gpt-4-turbo - Issue Summary': 'Intense pain and bleeding from dental issue',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My daughter fell and hit her head during the seizure. She has a bad cut and is bleeding!"',
#   'gpt-4-turbo - Summary': 'Daughter injured head, bleeding after seizure.',
#   'gpt-4-turbo - Issue': 'Daughter fell and sustained head injury during a seizure',
#   'gpt-4-turbo - Issue Summary': 'Head injury with bleeding from a fall during seizure',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My coworker is experiencing severe testicular pain and swelling. Please send an ambulance immediately!"',
#   'gpt-4-turbo - Summary': 'Coworker has severe testicular pain, swelling; needs ambulance ASAP.',
#   'gpt-4-turbo - Issue': 'Severe testicular pain and swelling',
#   'gpt-4-turbo - Issue Summary': 'Coworker with severe testicular pain, needs urgent help.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My arm hurts so much I can't even touch it. It feels like it's on fire and I can't move it.",
#   'gpt-4-turbo - Summary': 'Arm pain, feels like fire, immobile.',
#   'gpt-4-turbo - Issue': 'Severe arm pain with inability to move',
#   'gpt-4-turbo - Issue Summary': 'Intense arm pain, feels like fire, immobile',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I\'m at [Address] and I need an ambulance immediately. I... I\'m feeling suicidal and I can\'t think straight. Please hurry."',
#   'gpt-4-turbo - Summary': 'Urgent: Suicidal, needs immediate ambulance at [Address].',
#   'gpt-4-turbo - Issue': 'Patient reports feeling suicidal and unable to think straight.',
#   'gpt-4-turbo - Issue Summary': 'Suicidal feelings and mental disorientation.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I\'m not sure if I can make it through another minute. Please, I need help. I need someone to talk to."',
#   'gpt-4-turbo - Summary': 'Person feels overwhelmed, urgently needs to talk.',
#   'gpt-4-turbo - Issue': 'Patient expressing urgent distress and need for support',
#   'gpt-4-turbo - Issue Summary': 'Urgent emotional distress, needs immediate support',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"The man on the street is clutching his chest and gasping for air, he needs help!"',
#   'gpt-4-turbo - Summary': 'Man clutching chest, gasping, needs immediate help.',
#   'gpt-4-turbo - Issue': 'Man clutching chest and gasping for air',
#   'gpt-4-turbo - Issue Summary': 'Possible acute coronary syndrome',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I need help. Please, I\'m feeling so hopeless and I don\'t know what else to do. I... I can\'t go on like this."',
#   'gpt-4-turbo - Summary': 'Person feels hopeless, needs urgent help.',
#   'gpt-4-turbo - Issue': 'Patient expressing feelings of hopelessness and distress',
#   'gpt-4-turbo - Issue Summary': 'Patient feels hopeless and unable to continue',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I\'m sorry to bother you. I just... I don\'t know what else to do. I need help."',
#   'gpt-4-turbo - Summary': 'Person apologizes, feels lost, seeks help.',
#   'gpt-4-turbo - Issue': 'Patient expressing distress and seeking help',
#   'gpt-4-turbo - Issue Summary': 'Patient unsure and requesting assistance',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"I\'m experiencing intense pressure and tightness in my chest, it feels like someone is squeezing my heart, I\'m also feeling nauseous and lightheaded."',
#   'gpt-4-turbo - Summary': 'Experiencing chest pressure, nausea, and lightheadedness.',
#   'gpt-4-turbo - Issue': 'Chest pressure and tightness, nausea, lightheadedness',
#   'gpt-4-turbo - Issue Summary': 'Intense chest pressure with nausea and lightheadedness',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My leg is bleeding and it looks like it's broken. It's really swollen and painful.",
#   'gpt-4-turbo - Summary': 'Leg bleeding, appears broken, swollen, and painful.',
#   'gpt-4-turbo - Issue': 'Leg injury with bleeding and suspected fracture',
#   'gpt-4-turbo - Issue Summary': 'Bleeding leg with possible broken bone and swelling.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My coworker is allergic to tree nuts and accidentally ate some. Please send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Coworker ate nuts, allergic; need ambulance immediately.',
#   'gpt-4-turbo - Issue': 'Allergic reaction to tree nuts',
#   'gpt-4-turbo - Issue Summary': 'Coworker ingested tree nuts, has allergy',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I'm feeling very short of breath and my oxygen levels are low. I have a fever and a persistent cough. I'm also experiencing muscle aches.",
#   'gpt-4-turbo - Summary': 'Low oxygen, fever, cough, muscle aches; breathing difficulty.',
#   'gpt-4-turbo - Issue': 'Patient experiencing severe respiratory symptoms',
#   'gpt-4-turbo - Issue Summary': 'Shortness of breath, low oxygen, fever, cough, muscle aches',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My son touched a plant he\'s allergic to and now he\'s covered in hives. Please send help quickly!"',
#   'gpt-4-turbo - Summary': 'Son touched allergenic plant, has hives, needs urgent help.',
#   'gpt-4-turbo - Issue': 'Allergic reaction to plant contact',
#   'gpt-4-turbo - Issue Summary': 'Son has hives from plant allergy, needs urgent help.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My girlfriend\'s birth control pill failed, and she\'s worried about pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Girlfriend's pill failed, fears pregnancy, requests ambulance.",
#   'gpt-4-turbo - Issue': 'Failed contraception leading to pregnancy concerns',
#   'gpt-4-turbo - Issue Summary': 'Concern over failed birth control pill.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"It\'s Dr. Davis from County Hospital. We need to transfer Ms. Maria Jones, room 201. She\'s experiencing complications from her recent surgery."',
#   'gpt-4-turbo - Summary': 'Dr. Davis requests transfer for Ms. Jones due to surgery complications.',
#   'gpt-4-turbo - Issue': 'Complications from recent surgery',
#   'gpt-4-turbo - Issue Summary': 'Post-surgical complications needing hospital transfer.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My neighbor is lying on the ground! He's making weird noises and his eyes are rolled back.",
#   'gpt-4-turbo - Summary': 'Neighbor on ground, unresponsive, making strange noises.',
#   'gpt-4-turbo - Issue': 'Neighbor found unconscious with abnormal symptoms',
#   'gpt-4-turbo - Issue Summary': 'Neighbor unconscious, making noises, eyes rolled back.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
# ...
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My son has epilepsy and he missed his medication this morning. He\'s now having a seizure. What should I do?"',
#   'gpt-4-turbo - Summary': 'Son missed epilepsy medication, now seizing. What to do?',
#   'gpt-4-turbo - Issue': 'Epileptic seizure due to missed medication',
#   'gpt-4-turbo - Issue Summary': 'Child experiencing seizure from missed epilepsy meds',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My partner\'s dental filling came out and is causing excruciating pain. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Partner's filling out, in severe pain, needs ambulance.",
#   'gpt-4-turbo - Issue': 'Dental filling came out causing severe pain',
#   'gpt-4-turbo - Issue Summary': 'Excruciating pain from lost dental filling.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My leg is extremely swollen and bruised. I can't move it and I'm in a lot of pain.",
#   'gpt-4-turbo - Summary': 'Leg swollen, bruised, immobile, painful.',
#   'gpt-4-turbo - Issue': 'Swollen and bruised leg with immobility and severe pain',
#   'gpt-4-turbo - Issue Summary': 'Severe leg swelling and pain, unable to move leg.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"A man at the car wash just fell and isn\'t responding. We need an ambulance immediately!"',
#   'gpt-4-turbo - Summary': 'Man fell at car wash, unresponsive; needs ambulance immediately.',
#   'gpt-4-turbo - Issue': 'Man unresponsive after falling at a car wash',
#   'gpt-4-turbo - Issue Summary': 'Unresponsive man post-fall needing urgent help',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"Hello, this is Nurse Brown from Willow Creek Hospital. We\'re requesting a transfer for Mrs. Mary Black, room 103. She\'s having a severe postpartum hemorrhage."',
#   'gpt-4-turbo - Summary': 'Requesting transfer for severe postpartum hemorrhage, Willow Creek Hospital.',
#   'gpt-4-turbo - Issue': 'Severe postpartum hemorrhage',
#   'gpt-4-turbo - Issue Summary': 'Urgent transfer request for severe bleeding post-birth.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My dad isn\'t responding and I can\'t feel a heartbeat. I think he\'s having cardiac arrest!"',
#   'gpt-4-turbo - Summary': 'Dad unresponsive, suspected cardiac arrest, no heartbeat detected.',
#   'gpt-4-turbo - Issue': 'Patient unresponsive and potentially in cardiac arrest',
#   'gpt-4-turbo - Issue Summary': 'Unresponsive, no heartbeat, possible cardiac arrest',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My brother was diagnosed with a brain tumor a year ago, and he\'s now having a seizure. Could this be a sign of tumor growth?"',
#   'gpt-4-turbo - Summary': "Brother's seizure may indicate tumor growth; diagnosed last year.",
#   'gpt-4-turbo - Issue': 'Brother experiencing a seizure, previously diagnosed with brain tumor',
#   'gpt-4-turbo - Issue Summary': 'Seizure in patient with brain tumor history',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My friend\'s contraceptive sponge didn\'t work, and she\'s worried about pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Friend's contraceptive failed, fears pregnancy, requests ambulance.",
#   'gpt-4-turbo - Issue': 'Failed contraception leading to pregnancy concerns',
#   'gpt-4-turbo - Issue Summary': 'Concern over failed contraceptive sponge.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My daughter has a severe allergy to peanuts and accidentally ingested some. Please send help fast!"',
#   'gpt-4-turbo - Summary': 'Daughter ingested peanuts, severe allergy, needs immediate help.',
#   'gpt-4-turbo - Issue': 'Severe peanut allergy reaction',
#   'gpt-4-turbo - Issue Summary': 'Daughter ingested peanuts, severe allergic reaction.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I have osteoporosis and I fell. I'm afraid I might have broken my leg.",
#   'gpt-4-turbo - Summary': 'Osteoporosis patient fell, fears broken leg.',
#   'gpt-4-turbo - Issue': 'Possible broken leg due to a fall in a patient with osteoporosis',
#   'gpt-4-turbo - Issue Summary': 'Elderly osteoporosis patient fears broken leg after fall.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I'm experiencing shortness of breath and a racing heart. I have a fever and a cough. I also have a sore throat and a runny nose. I am pregnant.",
#   'gpt-4-turbo - Summary': 'Pregnant, experiencing fever, respiratory symptoms.',
#   'gpt-4-turbo - Issue': 'Patient reports multiple symptoms including respiratory issues and fever',
#   'gpt-4-turbo - Issue Summary': 'Shortness of breath, fever, cough, and pregnancy',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"I have other commitments that I can\'t cancel."',
#   'gpt-4-turbo - Summary': 'Person unable to cancel existing commitments.',
#   'gpt-4-turbo - Issue': 'Invalid',
#   'gpt-4-turbo - Issue Summary': 'Invalid',
#   'gpt-4-turbo - Severity': 'Invalid',
#   'gpt-4-turbo - Clinician to Contact': 'Invalid'},
#  {'Transcript': "My grandmother is gasping for air. She's been coughing up phlegm and has a high temperature. She also has a decreased level of consciousness. She is on a home ventilator.",
#   'gpt-4-turbo - Summary': 'Grandmother with severe respiratory symptoms, using home ventilator.',
#   'gpt-4-turbo - Issue': 'Grandmother experiencing severe respiratory distress',
#   'gpt-4-turbo - Issue Summary': 'Gasping for air, coughing phlegm, high fever, decreased consciousness.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My husband clutched his chest and collapsed. He\'s not breathing. I need an ambulance right away!"',
#   'gpt-4-turbo - Summary': 'Husband collapsed, not breathing, needs ambulance immediately.',
#   'gpt-4-turbo - Issue': 'Husband collapsed and is not breathing',
#   'gpt-4-turbo - Issue Summary': 'Husband collapsed, chest clutching, not breathing',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "Hello, I need an ambulance. I've been having this terrible pain in my head. It's like a pressure building up. I don't know what's wrong. I don't know if it's a brain tumor. I don't know what to do.",
#   'gpt-4-turbo - Summary': 'Person experiencing severe headache, fears brain tumor, seeks ambulance.',
#   'gpt-4-turbo - Issue': 'Severe headache with pressure sensation',
#   'gpt-4-turbo - Issue Summary': 'Patient reports severe, building pressure in head.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"My girlfriend\'s contraceptive shot wore off, and she\'s worried about pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Girlfriend fears pregnancy after contraceptive failure; requests ambulance.',
#   'gpt-4-turbo - Issue': 'Concern about failed contraception',
#   'gpt-4-turbo - Issue Summary': "Girlfriend's contraceptive shot wore off, worried about pregnancy.",
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My child has severe tooth pain and swelling. We can\'t control the bleeding. Please send help!"',
#   'gpt-4-turbo - Summary': 'Child with severe tooth pain, swelling, bleeding; needs help.',
#   'gpt-4-turbo - Issue': 'Severe tooth pain and swelling with uncontrollable bleeding in a child.',
#   'gpt-4-turbo - Issue Summary': 'Child with severe tooth pain, swelling, and major bleeding.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"Dr. Rodriguez here from Pinewood Hospital. I\'d like to request a Level 2 transfer for Mr. Daniel White, room 101. He\'s experiencing a possible acute renal failure."',
#   'gpt-4-turbo - Summary': 'Request Level 2 transfer for acute renal failure, patient White.',
#   'gpt-4-turbo - Issue': 'Request for Level 2 transfer due to possible acute renal failure',
#   'gpt-4-turbo - Issue Summary': 'Level 2 transfer for acute renal failure',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "I'm having difficulty breathing and my chest feels tight. I have a fever and a headache. I'm also experiencing fatigue and muscle pain. I recently traveled to a country with high COVID-19 rates.",
#   'gpt-4-turbo - Summary': 'Difficulty breathing, fever, headache, traveled to high COVID-19 area.',
#   'gpt-4-turbo - Issue': 'Difficulty breathing, chest tightness, fever, headache, fatigue, muscle pain, recent travel to high COVID-19 rate area.',
#   'gpt-4-turbo - Issue Summary': 'Respiratory distress with potential COVID-19 exposure.',
#   'gpt-4-turbo - Severity': 'Medium',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"Please, help me! I\'ve been in a car accident. I think I\'m bleeding internally. It hurts so bad."',
#   'gpt-4-turbo - Summary': 'Urgent: Car accident, possible internal bleeding, severe pain.',
#   'gpt-4-turbo - Issue': 'Car accident with suspected internal bleeding',
#   'gpt-4-turbo - Issue Summary': 'Suspected internal bleeding post car accident.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My husband is in palliative care and he\'s experiencing severe pain that his medication isn\'t controlling."',
#   'gpt-4-turbo - Summary': 'Husband in palliative care, suffering uncontrolled severe pain.',
#   'gpt-4-turbo - Issue': 'Severe pain in palliative care patient',
#   'gpt-4-turbo - Issue Summary': 'Palliative care patient with uncontrolled severe pain.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"In my culture, we don\'t go to the hospital unless it\'s absolutely necessary."',
#   'gpt-4-turbo - Summary': 'Cultural norm: hospital visits for severe cases only.',
#   'gpt-4-turbo - Issue': 'Invalid',
#   'gpt-4-turbo - Issue Summary': 'Invalid',
#   'gpt-4-turbo - Severity': 'Invalid',
#   'gpt-4-turbo - Clinician to Contact': 'Invalid'},
#  {'Transcript': '"My elderly parent is experiencing severe burning during urination and is unable to urinate. Send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Elderly parent, severe burning urination, unable to urinate, needs ambulance.',
#   'gpt-4-turbo - Issue': 'Severe burning during urination and inability to urinate in an elderly patient.',
#   'gpt-4-turbo - Issue Summary': 'Elderly patient with severe urinary discomfort.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My daughter is unconscious! She's been complaining of a stiff neck and now she's unresponsive.",
#   'gpt-4-turbo - Summary': 'Daughter unconscious, stiff neck, now unresponsive.',
#   'gpt-4-turbo - Issue': 'Daughter unconscious with prior complaint of stiff neck',
#   'gpt-4-turbo - Issue Summary': 'Unresponsive with stiff neck symptoms',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My friend has severe genital itching and burning sensation. We suspect a urinary tract infection. Send help!"',
#   'gpt-4-turbo - Summary': 'Friend has severe genital itching, suspects urinary infection, needs help.',
#   'gpt-4-turbo - Issue': 'Severe genital itching and burning sensation suspected to be a urinary tract infection.',
#   'gpt-4-turbo - Issue Summary': 'Suspected urinary tract infection with severe symptoms.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"This is Nurse Miller from Sunset Hospital. We have a patient, Mrs. Susan Garcia, in room 301, who needs an urgent transfer. She\'s experiencing severe pain and possible kidney stones."',
#   'gpt-4-turbo - Summary': 'Urgent transfer needed for patient with severe pain, possible kidney stones.',
#   'gpt-4-turbo - Issue': 'Urgent transfer needed for patient with severe pain and possible kidney stones.',
#   'gpt-4-turbo - Issue Summary': 'Severe pain, potential kidney stones, requires transfer.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "Can you send an ambulance to [fictitious address]? I've been bleeding a lot. I don't know what happened. I don't know how it happened. I don't know if it's serious.",
#   'gpt-4-turbo - Summary': 'Urgent ambulance requested for severe, unexplained bleeding.',
#   'gpt-4-turbo - Issue': 'Excessive bleeding',
#   'gpt-4-turbo - Issue Summary': 'Patient reports significant blood loss, unsure of cause.',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Transcript': '"My friend\'s dental implant fell out and is causing intense pain and bleeding. Send help urgently!"',
#   'gpt-4-turbo - Summary': 'Dental implant fell out; causing pain, bleeding; needs urgent help.',
#   'gpt-4-turbo - Issue': 'Dental implant fell out, causing pain and bleeding.',
#   'gpt-4-turbo - Issue Summary': 'Intense pain and bleeding from dental implant issue.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My friend\'s dental implant fell out and is causing intense pain and bleeding. Send help urgently!"',
#   'gpt-4-turbo - Summary': 'Dental implant fell out; causing pain, bleeding; needs urgent help.',
#   'gpt-4-turbo - Issue': 'Dental implant fell out causing pain and bleeding',
#   'gpt-4-turbo - Issue Summary': 'Intense pain and bleeding from dental implant issue.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': "My husband just collapsed! He's not breathing and I can't wake him up!",
#   'gpt-4-turbo - Summary': 'Husband collapsed, not breathing, unresponsive.',
#   'gpt-4-turbo - Issue': 'Husband collapsed and is unresponsive',
#   'gpt-4-turbo - Issue Summary': 'Husband collapsed, not breathing, unresponsive',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My partner\'s dental filling came out and is causing excruciating pain. Send an ambulance!"',
#   'gpt-4-turbo - Summary': "Partner's filling out, in severe pain, needs ambulance.",
#   'gpt-4-turbo - Issue': 'Dental filling came out causing severe pain',
#   'gpt-4-turbo - Issue Summary': 'Excruciating pain from lost dental filling.',
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My girlfriend\'s contraceptive shot wore off, and she\'s worried about pregnancy. Send an ambulance!"',
#   'gpt-4-turbo - Summary': 'Girlfriend fears pregnancy after contraceptive failure; requests ambulance.',
#   'gpt-4-turbo - Issue': 'Concern about failed contraception',
#   'gpt-4-turbo - Issue Summary': "Girlfriend's contraceptive shot wore off, worried about pregnancy.",
#   'gpt-4-turbo - Severity': 'Low',
#   'gpt-4-turbo - Clinician to Contact': 'general'},
#  {'Transcript': '"My neighbor is on the ground, not breathing, and without a pulse. Please send help fast!"',
#   'gpt-4-turbo - Summary': 'Neighbor unconscious, not breathing, needs urgent help.',
#   'gpt-4-turbo - Issue': 'Neighbor not breathing and without pulse',
#   'gpt-4-turbo - Issue Summary': 'Neighbor unresponsive, lacks pulse and breathing',
#   'gpt-4-turbo - Severity': 'High',
#   'gpt-4-turbo - Clinician to Contact': 'general'}]

# %%
RAW_SUMMARY_OUTPUT
# Out:
# ['Urgent transfer needed for stroke patient in room 205.',
#  'Friend ingested soy, has allergy, needs immediate help.',
#  'Post-seizure confusion; memory loss; seeks normalcy confirmation.',
#  'Man fell, unresponsive, no pulse at restaurant; needs urgent help.',
#  'Slipped on ice, leg injury, possible break.',
#  'Daughter grunts during seizure; parent questions normalcy.',
#  'Person fears hospital solitude; seeks companionship.',
#  'Accident victim bleeding, urgently needs help.',
#  'Daughter with asthma history has chest pain, breathing issues.',
#  'Friend had seizure, memory loss, disoriented.',
#  'Sister unconscious, previously hallucinating.',
#  "Sister ate sesame, can't breathe, needs ambulance.",
#  'Elderly parent with severe flank pain, needs ambulance now.',
#  'Parent lacks childcare support.',
#  'Child with tooth abscess in pain; needs ambulance.',
#  'Wife fell, not breathing, no pulse; needs urgent ambulance.',
#  'Requesting transfer for severely dehydrated patient with electrolyte imbalance.',
#  'Father experiencing speech difficulty and weakness.',
#  'Daughter in severe stomach pain, fearing appendicitis, seeking ambulance.',
#  'Person experiencing numb, tingly arm; fears stroke; seeks ambulance.',
#  'Feeling of failure, desire to escape problems.',
#  'Husband with lung cancer has worsening cough, chills, headache.',
#  'Friend stung by bee, throat closing, needs medical help.',
#  'Struggling long-term, needs immediate help.',
#  'Stabbed, bleeding heavily, urgently needs help.',
#  'Person collapsed at pool, needs immediate medical help, not breathing.',
#  'Elderly parent, severe burning urination, unable to urinate, needs ambulance.',
#  "Friend's contraceptive failed, fears pregnancy, requests ambulance.",
#  'Friend collapsed, not breathing, CPR started, need help.',
#  'Concern over failed contraceptive shot, possible pregnancy, requests ambulance.',
#  'Person at [Address] experiencing suicidal thoughts, needs immediate help.',
#  'Sudden severe back pain, frequent urination; needs ambulance urgently.',
#  'Individual asserts independence, declines assistance.',
#  'Person fears hospitals, avoids going.',
#  "Re-injured previously fractured arm, worried it's broken again.",
#  "Husband ate shellfish, can't breathe, needs ambulance.",
#  'Friend unconscious, feeling weak, now immobile.',
#  'Avoiding public disturbance; prefers discretion.',
#  'Elderly neighbor collapsed, unresponsive, possible seizure.',
#  'Son seizing, tongue bitten, bleeding heavily.',
#  'Ill with respiratory symptoms, heart disease history, recent heart attack.',
#  "Father's dentures stuck; can't breathe. Need ambulance immediately.",
#  'Husband has left arm, shoulder pain; feels anxious.',
#  "Child's tooth knocked out, heavy bleeding, urgent help needed.",
#  'Ill, low oxygen, fever, cough, pain; on immunosuppressants.',
#  'Man collapsed at concert, possibly in cardiac arrest.',
#  'Grandmother unconscious during dinner; needs immediate help.',
#  'Dr. Lee requests transfer for patient with acute kidney injury.',
#  'Child choking on retainer, needs ambulance immediately.',
#  'Daughter with COVID-19 symptoms, immunocompromised, needs urgent care.',
#  'Housebound; needs to return library books.',
#  'Mother in palliative care, needs ambulance for breathing trouble.',
#  "Girlfriend's contraception failed, fears pregnancy, requests ambulance.",
#  'Neighbor seizing, jerking violently; seeking immediate help.',
#  'Father unresponsive, dizzy, collapsed.',
#  'Woman on train has severe back pain, feels faint.',
#  "Coworker's loose dental crown causing pain, bleeding; needs urgent help.",
#  'Friend experiencing severe chest pain, nausea, needs immediate help.',
#  'Person overwhelmed, urgently needs someone to talk to.',
#  "Coworker's dental crown stuck in throat; need ambulance immediately.",
#  'Daughter has COVID-19 symptoms, breathing difficulty, fever, confusion.',
#  'Neighbor touched latex, is fainting; needs ambulance.',
#  'Mother in end-of-life care, severe nausea, needs medical help.',
#  "Brother's seizure possibly linked to recent head injury.",
#  "Daughter's persistent nosebleeds, parent worried, seeking ambulance.",
#  "Daughter's irregular medication possibly causing seizures.",
#  'Baby with seizure and high fever; parent extremely worried.',
#  "Girlfriend's contraceptive failed, fears pregnancy, requests ambulance.",
#  'Wife unconscious, having seizures, unresponsive.',
#  'Mother turning blue during seizure; fears of oxygen deprivation.',
#  'Colleague collapsed, not breathing, no pulse, need ambulance for CPR.',
#  'Patient needs urgent transfer for severe preeclampsia.',
#  "Promised to help friend move; can't cancel.",
#  'No details provided; financial concern about medical costs.',
#  'Transfer Ms. Jones for possible metabolic encephalopathy.',
#  'Mother in severe pain, medication failing, needs ambulance immediately.',
#  'Leg possibly re-broken; pain similar to previous incident.',
#  'Mother in end-of-life care, severe nausea; needs medical help.',
#  'Daughter in pain, possibly ear infection, seeking medical help.',
#  'Fear of hospitals expressed; no details or context provided.',
#  "Wife's contraceptive failure, fears pregnancy, requests ambulance.",
#  'Request Level 2 transfer for acute pancreatitis, patient White.',
#  'Person shot, bleeding from chest, losing strength, seeks help.',
#  'Elderly mother with heart attack, has hypertension and diabetes.',
#  'Person feels overwhelmed, needs to talk.',
#  'Friend with abdominal pain, vomiting, fever; possible appendicitis concern.',
#  "Coworker's dental crown fell out; needs urgent help for pain.",
#  'Daughter injured head, bleeding after seizure.',
#  'Coworker has severe testicular pain, swelling; needs ambulance ASAP.',
#  'Arm pain, feels like fire, immobile.',
#  'Urgent: Suicidal, needs immediate ambulance at [Address].',
#  'Person feels overwhelmed, urgently needs to talk.',
#  'Man clutching chest, gasping, needs immediate help.',
#  'Person feels hopeless, needs urgent help.',
#  'Person apologizes, feels lost, seeks help.',
#  'Experiencing chest pressure, nausea, and lightheadedness.',
#  'Leg bleeding, appears broken, swollen, and painful.',
#  'Coworker ate nuts, allergic; need ambulance immediately.',
#  'Low oxygen, fever, cough, muscle aches; breathing difficulty.',
#  'Son touched allergenic plant, has hives, needs urgent help.',
#  "Girlfriend's pill failed, fears pregnancy, requests ambulance.",
#  'Dr. Davis requests transfer for Ms. Jones due to surgery complications.',
#  'Neighbor on ground, unresponsive, making strange noises.',
#  'Post-surgery leg pain and swelling experienced.',
#  "Feeling isolated, seeks help; family doesn't understand.",
#  "Child's severe toothache caused fainting; needs urgent medical help.",
#  "Woman collapsed, unresponsive at doctor's; needs ambulance now.",
#  "Wife's contraceptive patch off, fears pregnancy, requests ambulance.",
#  'Sleep deprivation in son possibly causing seizures.',
#  'Heavy period, unstoppable bleeding, feeling weak.',
#  'Husband collapsed, heart attack, unresponsive, needs immediate help.',
#  'Foot numb, tingling, painful; toes lack sensation.',
#  'Pregnant woman experiencing seizure, seeks immediate help.',
#  'Fell, leg injury, throbbing, immobile.',
#  'Injured in fight, suspects internal bleeding, breathing difficulty, weakness.',
#  'Husband in motorcycle crash, arm pain, mobility issue.',
#  'Grandfather has intense back pain, breathing difficulties.',
#  "Wife's contraceptive failure, fears pregnancy, requests ambulance.",
#  'Leg movement causes severe pain, untouchable.',
#  'Seeking relief from pain, desires help.',
#  'Father in palliative care, experiencing hallucinations, needs ambulance.',
#  'Husband unresponsive, not breathing; immediate help requested.',
#  'Nurse requests transfer for patient with possible broken leg.',
#  'Brother unconscious, previously anxious, now fainted.',
#  'Gym-goer collapsed, unresponsive, no pulse detected.',
#  'Brother has hives from dairy, needs urgent help.',
#  'Coworker collapsed, not breathing, no pulse, CPR started, need ambulance.',
#  'Husband has worsening cough, breathing issues, chills, headache.',
#  "Dad's heart attack, collapsed, not breathing, needs urgent help.",
#  'Emergency: Dad unresponsive, needs ambulance immediately.',
#  'Chest tightness, difficulty breathing, fears heart attack, seeks ambulance.',
#  'Person poisoned, feeling dizzy and nauseous, needs ambulance.',
#  'Person needs ambulance and help urgently.',
#  'Mother unresponsive, confused, collapsed.',
#  'Requesting transfer for severe asthma attack, Mountainside Hospital.',
#  'Injured, numb fingers; requests immediate help.',
#  "Friend meeting; can't leave house.",
#  'Person feels overwhelmed, urgently needs help.',
#  "Ambulance needed for daughter's seizure, foaming, rigidity.",
#  'Neighbor fell, not breathing, heart stopped, needs immediate help.',
#  'Girlfriend had seizure, now unresponsive; seeks immediate advice.',
#  'Child with allergies has wheezing, cough, fever, rash.',
#  'Friend unconscious from drinking, needs immediate help.',
#  'Son with heart issues has chest pain, arm tingling.',
#  'Leg pain, swelling, possible break, unable to walk.',
#  'Child has severe bladder spasms, needs urgent help.',
#  'Friend has severe genital itching, suspects urinary infection, needs help.',
#  'Request for ambulance due to severe leg pain, possible clot.',
#  'Job loss fear if work missed.',
#  'Dr. Johnson requests transfer for patient with bowel obstruction.',
#  'Friend unresponsive, no pulse, chest pain reported.',
#  "Friend with severe groin pain, can't urinate, needs ambulance.",
#  'Car accident, leg trapped and possibly broken.',
#  'Person feels shaky, needs ambulance, suspects neurological issue.',
#  'Person avoids hospital, reasons unspecified, needs summarizing.',
#  'Elderly parent, severe burning urination, unable to urinate, needs ambulance.',
#  'Grandmother has jaw pain, breathing difficulties.',
#  'Concerned about pregnancy after contraceptive ring fell out.',
#  'Leg bent, appears broken.',
#  'Wife in palliative care, difficulty swallowing, coughing blood. Concerned.',
#  'Partner has severe pelvic pain, needs urgent ambulance.',
#  "Daughter ate peanuts, can't breathe, needs ambulance.",
#  'Test tomorrow; attendance necessary.',
#  "Wife's arm painful, deformed after car accident.",
#  'Neighbor with severe urinary incontinence; needs ambulance urgently.',
#  'Customer unresponsive, suspected cardiac arrest in store.',
#  'Baby with rare condition bleeding, urgently needs doctor.',
#  'Son missed epilepsy medication, now seizing. What to do?',
#  "Partner's filling out, in severe pain, needs ambulance.",
#  'Leg swollen, bruised, immobile, painful.',
#  'Man fell at car wash, unresponsive; needs ambulance immediately.',
#  'Requesting transfer for severe postpartum hemorrhage, Willow Creek Hospital.',
#  'Dad unresponsive, suspected cardiac arrest, no heartbeat detected.',
#  "Brother's seizure may indicate tumor growth; diagnosed last year.",
#  "Friend's contraceptive failed, fears pregnancy, requests ambulance.",
#  'Daughter ingested peanuts, severe allergy, needs immediate help.',
#  'Osteoporosis patient fell, fears broken leg.',
#  'Pregnant, experiencing fever, respiratory symptoms.',
#  'Person unable to cancel existing commitments.',
#  'Grandmother with severe respiratory symptoms, using home ventilator.',
#  'Husband collapsed, not breathing, needs ambulance immediately.',
#  'Person experiencing severe headache, fears brain tumor, seeks ambulance.',
#  'Girlfriend fears pregnancy after contraceptive failure; requests ambulance.',
#  'Child with severe tooth pain, swelling, bleeding; needs help.',
#  'Request Level 2 transfer for acute renal failure, patient White.',
#  'Difficulty breathing, fever, headache, traveled to high COVID-19 area.',
#  'Urgent: Car accident, possible internal bleeding, severe pain.',
#  'Husband in palliative care, suffering uncontrolled severe pain.',
#  'Cultural norm: hospital visits for severe cases only.',
#  'Elderly parent, severe burning urination, unable to urinate, needs ambulance.',
#  'Daughter unconscious, stiff neck, now unresponsive.',
#  'Friend has severe genital itching, suspects urinary infection, needs help.',
#  'Urgent transfer needed for patient with severe pain, possible kidney stones.',
#  'Urgent ambulance requested for severe, unexplained bleeding.',
#  'Dental implant fell out; causing pain, bleeding; needs urgent help.',
#  'Dental implant fell out; causing pain, bleeding; needs urgent help.',
#  'Husband collapsed, not breathing, unresponsive.',
#  "Partner's filling out, in severe pain, needs ambulance.",
#  'Girlfriend fears pregnancy after contraceptive failure; requests ambulance.',
#  'Neighbor unconscious, not breathing, needs urgent help.']

# %%
RAW_CLASSIFIER_OUTPUT
# Out:
# [{'Issue': 'Urgent patient transfer required for potential stroke',
#   'Issue Summary': 'Patient showing stroke symptoms, needs urgent transfer.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Accidental ingestion of allergen (soy)',
#   'Issue Summary': 'Friend ingested soy, has known allergy',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': "Post-seizure confusion in patient's wife",
#   'Issue Summary': 'Wife experienced seizure, now confused and amnesic.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Man unresponsive with no pulse at a restaurant',
#   'Issue Summary': 'Unresponsive man, no pulse, emergency required',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Possible broken leg due to slipping on ice',
#   'Issue Summary': 'Patient suspects broken leg after slipping',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter experiencing seizure with grunting noises',
#   'Issue Summary': 'Seizure with abnormal vocalization in child',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Patient reports being in an accident with bleeding',
#   'Issue Summary': 'Accident with bleeding',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter experiencing chest pain and shortness of breath with asthma history.',
#   'Issue Summary': 'Asthmatic child with chest pain and breathing difficulty.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Friend experienced a seizure and has memory loss',
#   'Issue Summary': 'Seizure with postictal confusion',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Sister unconscious with prior hallucinations',
#   'Issue Summary': 'Unconsciousness following hallucinations',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Sister ingested sesame and is experiencing breathing difficulties.',
#   'Issue Summary': 'Sesame ingestion causing breathing issues.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Elderly parent with severe flank pain and hematuria',
#   'Issue Summary': 'Severe flank pain and blood in urine',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': "Neighbor's child with tooth abscess",
#   'Issue Summary': 'Child suffering from painful tooth abscess',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Wife fell and is unresponsive with no pulse',
#   'Issue Summary': 'Unresponsive and pulseless after a fall',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe dehydration and electrolyte imbalance',
#   'Issue Summary': 'Requesting transfer for dehydration and imbalance',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Father experiencing difficulty speaking and feeling weak',
#   'Issue Summary': 'Difficulty speaking and weakness',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter experiencing severe stomach pain',
#   'Issue Summary': 'Severe stomach pain, worsening, cause uncertain.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Numb and tingly arm with uncertainty about a stroke',
#   'Issue Summary': 'Patient reports numbness in arm, suspects stroke.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Expressing feelings of failure and despair',
#   'Issue Summary': 'Patient feels like a failure, wants to escape feelings',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Husband experiencing worsening respiratory symptoms with a history of lung cancer.',
#   'Issue Summary': 'Worsening cough, breathing issues, chills, headache.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Friend experiencing anaphylactic reaction from bee sting',
#   'Issue Summary': 'Bee sting causing throat closure, needs urgent help',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient expressing emotional distress and need for help',
#   'Issue Summary': 'Patient at breaking point, needs urgent help',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient reports being stabbed and experiencing heavy bleeding.',
#   'Issue Summary': 'Stabbed with major blood loss, needs urgent help.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': "Person collapsed and isn't breathing at the pool",
#   'Issue Summary': 'Individual collapsed, not breathing, requires urgent help',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe burning during urination and inability to urinate in an elderly patient.',
#   'Issue Summary': 'Elderly patient with severe urinary discomfort.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Failed contraception leading to pregnancy concerns',
#   'Issue Summary': 'Concerns over failed contraceptive sponge.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': "Friend collapsed and isn't breathing during a run.",
#   'Issue Summary': 'Friend collapsed, not breathing, CPR started.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Failed contraception leading to pregnancy concerns',
#   'Issue Summary': 'Concerned about pregnancy due to failed contraception.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient experiencing suicidal thoughts',
#   'Issue Summary': 'Patient at [Address] reports suicidal ideation.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Severe lower back pain and frequent urination',
#   'Issue Summary': 'Sudden severe back pain with frequent urination.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Fear of hospitals',
#   'Issue Summary': 'Patient expresses fear of hospital visits.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Re-injured previously fractured arm',
#   'Issue Summary': 'Swollen arm, possible re-fracture',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Accidental shellfish ingestion leading to breathing difficulties',
#   'Issue Summary': 'Shellfish allergy causing breathing issues.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Friend is unconscious and feeling very weak',
#   'Issue Summary': 'Unconsciousness with prior weakness',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Elderly neighbor collapsed and unresponsive, possible seizure',
#   'Issue Summary': 'Elderly neighbor collapsed, possibly seizing, unresponsive.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Son experiencing seizures and tongue injury with significant bleeding.',
#   'Issue Summary': 'Seizures with tongue injury and major blood loss.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient experiencing respiratory distress with fever, chills, and other symptoms.',
#   'Issue Summary': 'Respiratory distress and fever in a patient with heart disease history.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Dentures lodged in throat, difficulty breathing',
#   'Issue Summary': 'Father choking on dentures, needs urgent help',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Husband experiencing pain in left arm and shoulder with anxiety.',
#   'Issue Summary': 'Left arm and shoulder pain with anxiety.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': "Child's tooth knocked out with heavy bleeding",
#   'Issue Summary': 'Tooth loss and significant bleeding in child',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient experiencing multiple severe symptoms',
#   'Issue Summary': 'Shortness of breath, low oxygen, fever, cough, abdominal pain, diarrhea',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Man unresponsive at a concert, suspected cardiac arrest.',
#   'Issue Summary': 'Unresponsive man, likely cardiac arrest at concert.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Grandmother unconscious during dinner',
#   'Issue Summary': 'Elderly woman suddenly unconscious while eating.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Request for patient transfer due to possible acute kidney injury',
#   'Issue Summary': 'Transfer request for acute kidney injury',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Child choking on orthodontic retainer',
#   'Issue Summary': 'Child choking due to retainer in throat',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter experiencing respiratory distress and other symptoms',
#   'Issue Summary': 'Trouble breathing, fever, sore throat, confusion, COVID-19 contact',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Mother in palliative care with breathing difficulties',
#   'Issue Summary': 'Palliative care patient struggling to breathe',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Failed contraception leading to pregnancy concerns.',
#   'Issue Summary': 'Concerns over failed contraception and potential pregnancy.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Neighbor experiencing a seizure',
#   'Issue Summary': 'Neighbor having a violent seizure',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Father unresponsive after feeling dizzy and collapsing',
#   'Issue Summary': 'Elderly male collapsed, currently unresponsive',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe back pain and feeling faint',
#   'Issue Summary': 'Woman with severe back pain, feels faint',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Loose dental crown causing severe pain and bleeding',
#   'Issue Summary': 'Severe pain and bleeding from loose dental crown',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe chest pain with radiation to left arm, nausea, and lightheadedness.',
#   'Issue Summary': 'Friend experiencing severe chest pain and related symptoms.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient expressing emotional distress and urgent need for support',
#   'Issue Summary': 'Patient at emotional limit, seeks urgent help',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Dislodged dental crown stuck in throat',
#   'Issue Summary': 'Dental crown dislodged, causing choking hazard.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter experiencing respiratory distress and other symptoms after COVID-19 exposure.',
#   'Issue Summary': 'Respiratory distress, fever, confusion post-COVID exposure.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Neighbor experiencing an allergic reaction with fainting',
#   'Issue Summary': 'Latex allergy causing fainting, needs urgent help',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe nausea and vomiting in palliative care patient',
#   'Issue Summary': 'End-of-life care patient with severe nausea, vomiting, refusing meds.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Brother experiencing a seizure following a past head injury',
#   'Issue Summary': 'Post-head injury seizure occurrence',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Frequent nosebleeds in daughter',
#   'Issue Summary': 'Daughter experiencing persistent nosebleeds for days.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Epileptic seizure due to irregular medication intake',
#   'Issue Summary': 'Daughter experiencing seizure, possibly medication-related.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Baby experiencing a seizure and high fever',
#   'Issue Summary': 'Seizure and high fever in infant',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Failed contraceptive implant with pregnancy concern',
#   'Issue Summary': 'Concern over failed contraceptive implant.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Wife unconscious with prior seizures',
#   'Issue Summary': 'Unconscious following seizures',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Mother experiencing a seizure and turning blue',
#   'Issue Summary': 'Seizure with possible oxygen deprivation',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Colleague collapsed and is unresponsive',
#   'Issue Summary': 'Colleague collapsed, not breathing, no pulse, CPR initiated',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient requires immediate hospital transfer due to severe preeclampsia.',
#   'Issue Summary': 'Urgent transfer needed for severe preeclampsia.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Concern about affordability of ambulance and hospital services',
#   'Issue Summary': 'Patient worried about medical costs',
#   'Severity': 'Low',
#   'Clinician to Contact': 'support'},
#  {'Issue': 'Request for patient transfer due to possible metabolic encephalopathy',
#   'Issue Summary': 'Transfer needed for metabolic encephalopathy',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe pain in palliative care patient',
#   'Issue Summary': 'End-of-life care patient with uncontrolled severe pain.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Suspected broken leg',
#   'Issue Summary': 'Patient suspects leg is broken, similar pain as before.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe nausea and vomiting in palliative care patient',
#   'Issue Summary': 'End-of-life care patient with severe nausea, vomiting.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter experiencing severe ear pain',
#   'Issue Summary': 'Child with severe ear pain, possibly infection.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Fear of hospitals',
#   'Issue Summary': 'Patient expresses fear of hospitals.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Contraceptive patch came off',
#   'Issue Summary': 'Concern over potential pregnancy due to failed contraception.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Request for Level 2 transfer due to possible acute pancreatitis',
#   'Issue Summary': 'Level 2 hospital transfer for acute pancreatitis.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient reports being shot in the chest with active bleeding.',
#   'Issue Summary': 'Gunshot wound to chest with active bleeding.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Mother experiencing a heart attack',
#   'Issue Summary': '75-year-old with heart attack, has hypertension and diabetes.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient expressing emotional distress',
#   'Issue Summary': 'Patient feels overwhelmed and unable to cope',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Friend experiencing severe abdominal pain, vomiting, and fever.',
#   'Issue Summary': 'Severe abdominal pain with vomiting and fever.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Dental crown fell out causing pain and bleeding',
#   'Issue Summary': 'Intense pain and bleeding from dental issue',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter fell and sustained head injury during a seizure',
#   'Issue Summary': 'Head injury with bleeding from a fall during seizure',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe testicular pain and swelling',
#   'Issue Summary': 'Coworker with severe testicular pain, needs urgent help.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe arm pain with inability to move',
#   'Issue Summary': 'Intense arm pain, feels like fire, immobile',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient reports feeling suicidal and unable to think straight.',
#   'Issue Summary': 'Suicidal feelings and mental disorientation.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient expressing urgent distress and need for support',
#   'Issue Summary': 'Urgent emotional distress, needs immediate support',
#   'Severity': 'Low',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Man clutching chest and gasping for air',
#   'Issue Summary': 'Possible acute coronary syndrome',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient expressing feelings of hopelessness and distress',
#   'Issue Summary': 'Patient feels hopeless and unable to continue',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient expressing distress and seeking help',
#   'Issue Summary': 'Patient unsure and requesting assistance',
#   'Severity': 'Low',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Chest pressure and tightness, nausea, lightheadedness',
#   'Issue Summary': 'Intense chest pressure with nausea and lightheadedness',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Leg injury with bleeding and suspected fracture',
#   'Issue Summary': 'Bleeding leg with possible broken bone and swelling.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Allergic reaction to tree nuts',
#   'Issue Summary': 'Coworker ingested tree nuts, has allergy',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient experiencing severe respiratory symptoms',
#   'Issue Summary': 'Shortness of breath, low oxygen, fever, cough, muscle aches',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Allergic reaction to plant contact',
#   'Issue Summary': 'Son has hives from plant allergy, needs urgent help.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Failed contraception leading to pregnancy concerns',
#   'Issue Summary': 'Concern over failed birth control pill.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Complications from recent surgery',
#   'Issue Summary': 'Post-surgical complications needing hospital transfer.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Neighbor found unconscious with abnormal symptoms',
#   'Issue Summary': 'Neighbor unconscious, making noises, eyes rolled back.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Post-surgical leg pain and swelling',
#   'Issue Summary': 'Intense pain and swelling post leg surgery',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient expressing feelings of loneliness and despair',
#   'Issue Summary': 'Patient feels alone and seeks help',
#   'Severity': 'Low',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': "Child's severe toothache and fainting",
#   'Issue Summary': 'Severe toothache causing fainting in child.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': "Woman collapsed and is unresponsive at doctor's office.",
#   'Issue Summary': 'Unresponsive woman needs urgent ambulance.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Contraceptive patch came off, fear of pregnancy',
#   'Issue Summary': 'Fear of pregnancy due to contraceptive failure.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Son experiencing a seizure possibly due to sleep deprivation',
#   'Issue Summary': 'Seizure in sleep-deprived child',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Heavy menstrual bleeding and weakness',
#   'Issue Summary': 'Excessive bleeding and feeling weak',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Husband having a heart attack and collapsed',
#   'Issue Summary': 'Husband collapsed, unresponsive due to heart attack.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Numb and tingling foot with pain',
#   'Issue Summary': 'Patient reports numbness, tingling, and pain in foot.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Pregnant patient experiencing a seizure',
#   'Issue Summary': 'Pregnant and having a seizure, needs immediate help.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient fell and injured leg',
#   'Issue Summary': 'Leg injury from fall, unable to move it.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Internal bleeding and breathing difficulty following a fight',
#   'Issue Summary': 'Suspected internal bleeding, trouble breathing post-fight',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Motorcycle crash resulting in arm injury',
#   'Issue Summary': "Husband injured arm in motorcycle crash, can't move it.",
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Intense back pain and difficulty breathing',
#   'Issue Summary': 'Grandfather with severe back pain and breathing issues.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Contraceptive patch came off',
#   'Issue Summary': 'Concern over potential pregnancy due to contraceptive failure.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Excruciating leg pain on movement',
#   'Issue Summary': 'Severe leg pain with any movement',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient experiencing severe pain',
#   'Issue Summary': 'Patient requests help to alleviate severe pain.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Father in palliative care experiencing hallucinations and confusion',
#   'Issue Summary': 'Palliative care patient with hallucinations and confusion',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Husband not breathing and without a pulse',
#   'Issue Summary': 'Husband unresponsive, no pulse, requires immediate help',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Request for patient transfer due to a possible broken leg.',
#   'Issue Summary': 'Transfer needed for patient with potential broken leg.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Brother unconscious after experiencing anxiety',
#   'Issue Summary': 'Brother fainted following anxiety episode.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Unresponsive individual at gym without detectable pulse',
#   'Issue Summary': 'Individual collapsed, unresponsive, no pulse detected.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Brother experiencing allergic reaction to dairy',
#   'Issue Summary': 'Allergic reaction with hives due to dairy exposure.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Coworker collapsed and is unresponsive',
#   'Issue Summary': 'Coworker collapsed, not breathing, no pulse, CPR initiated.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Husband experiencing persistent cough, worsening breathing, chills, and headache.',
#   'Issue Summary': 'Persistent cough, breathing issues, chills, headache.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': "Patient's father experiencing a heart attack and is unresponsive.",
#   'Issue Summary': 'Heart attack with patient collapsed and not breathing.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': "Patient's father is unresponsive with no breathing or heartbeat.",
#   'Issue Summary': 'Father unresponsive, no breath or heartbeat.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient experiencing chest tightness and difficulty breathing.',
#   'Issue Summary': 'Chest tightness and breathing difficulty, possible heart issue.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Suspected poisoning',
#   'Issue Summary': 'Patient feels nauseous and dizzy, suspects poisoning.',
#   'Severity': 'High',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Patient requesting ambulance due to distress',
#   'Issue Summary': 'Patient in distress, requesting immediate help.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Mother unresponsive and collapsed',
#   'Issue Summary': 'Elderly female, unresponsive after confusion',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe asthma attack',
#   'Issue Summary': 'Patient experiencing severe asthma attack.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient reports bleeding and numbness in arm',
#   'Issue Summary': 'Bleeding from arm with loss of sensation in fingers',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Patient experiencing severe respiratory distress',
#   'Issue Summary': 'Patient feels like drowning, needs urgent help.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter experiencing a fit with severe symptoms',
#   'Issue Summary': 'Daughter foaming at mouth, body rigid.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Neighbor has collapsed and is not breathing with a stopped heart.',
#   'Issue Summary': 'Neighbor collapsed, not breathing, cardiac arrest.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Post-seizure unresponsiveness',
#   'Issue Summary': 'Girlfriend unresponsive after a seizure',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Son experiencing wheezing, rapid heartbeat, coughing, low-grade fever, and rash',
#   'Issue Summary': 'Child with allergy symptoms and respiratory distress',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Friend unconscious after consuming alcohol',
#   'Issue Summary': 'Unconscious post alcohol intake',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe chest pain and tingling in arm',
#   'Issue Summary': 'Son with heart history has severe chest pain',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe leg pain and swelling, possible fracture',
#   'Issue Summary': 'Severe leg pain, swelling, potential break',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe bladder spasms in child',
#   'Issue Summary': 'Child experiencing severe bladder spasms and pain.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe genital itching and suspected urinary tract infection',
#   'Issue Summary': 'Genital discomfort suspected as UTI',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Sharp stabbing pain in leg',
#   'Issue Summary': 'Patient reports sharp, stabbing leg pain, unsure of cause.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Request for patient transfer due to possible bowel obstruction',
#   'Issue Summary': 'Transfer request for bowel obstruction signs',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Friend unresponsive with no pulse and prior chest pain',
#   'Issue Summary': 'Possible cardiac arrest, unresponsive friend',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe groin pain and inability to urinate',
#   'Issue Summary': 'Severe groin pain, cannot urinate, needs urgent help.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Car accident with potential leg injury',
#   'Issue Summary': 'Leg possibly broken and trapped under dashboard.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient experiencing uncontrollable shakiness and movement',
#   'Issue Summary': 'Uncontrollable shakiness, possible neurological issue',
#   'Severity': 'High',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Severe burning during urination and inability to urinate in elderly parent.',
#   'Issue Summary': 'Elderly patient with severe urinary discomfort and retention.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Grandmother experiencing jaw pain and breathlessness',
#   'Issue Summary': 'Jaw pain and difficulty breathing',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Contraceptive ring dislodgement with pregnancy concern',
#   'Issue Summary': "Partner's contraceptive ring fell out, pregnancy risk.",
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Leg appears to be broken',
#   'Issue Summary': 'Patient reports leg bent at an odd angle, likely broken.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Wife in palliative care with swallowing difficulties and coughing up blood',
#   'Issue Summary': 'Palliative care patient with swallowing issues and hemoptysis',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe pelvic pain and difficulty urinating',
#   'Issue Summary': 'Urgent pelvic pain and urination difficulty',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter ingested peanuts and is experiencing breathing difficulties.',
#   'Issue Summary': 'Child with peanut allergy in respiratory distress.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Wife injured in car accident, arm deformed and painful',
#   'Issue Summary': 'Deformed and painful arm post car accident',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe urinary incontinence',
#   'Issue Summary': 'Neighbor with uncontrolled bladder incontinence.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Customer unresponsive, suspected cardiac arrest',
#   'Issue Summary': 'Unresponsive customer, possible cardiac arrest.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Newborn with a rare condition experiencing bleeding',
#   'Issue Summary': 'Newborn with rare condition, bleeding severely',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Epileptic seizure due to missed medication',
#   'Issue Summary': 'Child experiencing seizure from missed epilepsy meds',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Dental filling came out causing severe pain',
#   'Issue Summary': 'Excruciating pain from lost dental filling.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Swollen and bruised leg with immobility and severe pain',
#   'Issue Summary': 'Severe leg swelling and pain, unable to move leg.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Man unresponsive after falling at a car wash',
#   'Issue Summary': 'Unresponsive man post-fall needing urgent help',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe postpartum hemorrhage',
#   'Issue Summary': 'Urgent transfer request for severe bleeding post-birth.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient unresponsive and potentially in cardiac arrest',
#   'Issue Summary': 'Unresponsive, no heartbeat, possible cardiac arrest',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Brother experiencing a seizure, previously diagnosed with brain tumor',
#   'Issue Summary': 'Seizure in patient with brain tumor history',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Failed contraception leading to pregnancy concerns',
#   'Issue Summary': 'Concern over failed contraceptive sponge.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe peanut allergy reaction',
#   'Issue Summary': 'Daughter ingested peanuts, severe allergic reaction.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Possible broken leg due to a fall in a patient with osteoporosis',
#   'Issue Summary': 'Elderly osteoporosis patient fears broken leg after fall.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Patient reports multiple symptoms including respiratory issues and fever',
#   'Issue Summary': 'Shortness of breath, fever, cough, and pregnancy',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Grandmother experiencing severe respiratory distress',
#   'Issue Summary': 'Gasping for air, coughing phlegm, high fever, decreased consciousness.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Husband collapsed and is not breathing',
#   'Issue Summary': 'Husband collapsed, chest clutching, not breathing',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe headache with pressure sensation',
#   'Issue Summary': 'Patient reports severe, building pressure in head.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Concern about failed contraception',
#   'Issue Summary': "Girlfriend's contraceptive shot wore off, worried about pregnancy.",
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe tooth pain and swelling with uncontrollable bleeding in a child.',
#   'Issue Summary': 'Child with severe tooth pain, swelling, and major bleeding.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Request for Level 2 transfer due to possible acute renal failure',
#   'Issue Summary': 'Level 2 transfer for acute renal failure',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Difficulty breathing, chest tightness, fever, headache, fatigue, muscle pain, recent travel to high COVID-19 rate area.',
#   'Issue Summary': 'Respiratory distress with potential COVID-19 exposure.',
#   'Severity': 'Medium',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Car accident with suspected internal bleeding',
#   'Issue Summary': 'Suspected internal bleeding post car accident.',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe pain in palliative care patient',
#   'Issue Summary': 'Palliative care patient with uncontrolled severe pain.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Invalid',
#   'Issue Summary': 'Invalid',
#   'Severity': 'Invalid',
#   'Clinician to Contact': 'Invalid'},
#  {'Issue': 'Severe burning during urination and inability to urinate in an elderly patient.',
#   'Issue Summary': 'Elderly patient with severe urinary discomfort.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Daughter unconscious with prior complaint of stiff neck',
#   'Issue Summary': 'Unresponsive with stiff neck symptoms',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Severe genital itching and burning sensation suspected to be a urinary tract infection.',
#   'Issue Summary': 'Suspected urinary tract infection with severe symptoms.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Urgent transfer needed for patient with severe pain and possible kidney stones.',
#   'Issue Summary': 'Severe pain, potential kidney stones, requires transfer.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Excessive bleeding',
#   'Issue Summary': 'Patient reports significant blood loss, unsure of cause.',
#   'Severity': 'High',
#   'Clinician to Contact': 'Clinician to Contact Patient'},
#  {'Issue': 'Dental implant fell out, causing pain and bleeding.',
#   'Issue Summary': 'Intense pain and bleeding from dental implant issue.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Dental implant fell out causing pain and bleeding',
#   'Issue Summary': 'Intense pain and bleeding from dental implant issue.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Husband collapsed and is unresponsive',
#   'Issue Summary': 'Husband collapsed, not breathing, unresponsive',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Dental filling came out causing severe pain',
#   'Issue Summary': 'Excruciating pain from lost dental filling.',
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Concern about failed contraception',
#   'Issue Summary': "Girlfriend's contraceptive shot wore off, worried about pregnancy.",
#   'Severity': 'Low',
#   'Clinician to Contact': 'general'},
#  {'Issue': 'Neighbor not breathing and without pulse',
#   'Issue Summary': 'Neighbor unresponsive, lacks pulse and breathing',
#   'Severity': 'High',
#   'Clinician to Contact': 'general'}]

# %%
dfs = pd.DataFrame(PROCESSED_DATA)
dfs
# Out:
#                                             Transcript  \
# 0    "This is Nurse Thompson at Lakeside Hospital. ...
# 1    "My friend has a known allergy to soy and acci...
# 2    "My wife just stopped seizing, but she's confu...
# 3    "A man at the restaurant just fell and isn't r...
# 4    I slipped on the ice and my leg buckled. I thi...
# ..                                                 ...
# 195  "My friend's dental implant fell out and is ca...
# 196  My husband just collapsed! He's not breathing ...
# 197  "My partner's dental filling came out and is c...
# 198  "My girlfriend's contraceptive shot wore off, ...
# 199  "My neighbor is on the ground, not breathing, ...
#
#                                  gpt-4-turbo - Summary  \
# 0    Urgent transfer needed for stroke patient in r...
# 1    Friend ingested soy, has allergy, needs immedi...
# 2    Post-seizure confusion; memory loss; seeks nor...
# 3    Man fell, unresponsive, no pulse at restaurant...
# 4          Slipped on ice, leg injury, possible break.
# ..                                                 ...
# 195  Dental implant fell out; causing pain, bleedin...
# 196    Husband collapsed, not breathing, unresponsive.
# 197  Partner's filling out, in severe pain, needs a...
# 198  Girlfriend fears pregnancy after contraceptive...
# 199  Neighbor unconscious, not breathing, needs urg...
#
#                                    gpt-4-turbo - Issue  \
# 0    Urgent patient transfer required for potential...
# 1               Accidental ingestion of allergen (soy)
# 2             Post-seizure confusion in patient's wife
# 3       Man unresponsive with no pulse at a restaurant
# 4           Possible broken leg due to slipping on ice
# ..                                                 ...
# 195  Dental implant fell out causing pain and bleeding
# 196              Husband collapsed and is unresponsive
# 197        Dental filling came out causing severe pain
# 198                 Concern about failed contraception
# 199           Neighbor not breathing and without pulse
#
#                            gpt-4-turbo - Issue Summary gpt-4-turbo - Severity  \
# 0    Patient showing stroke symptoms, needs urgent ...                   High
# 1               Friend ingested soy, has known allergy                   High
# 2    Wife experienced seizure, now confused and amn...                   High
# 3       Unresponsive man, no pulse, emergency required                   High
# 4           Patient suspects broken leg after slipping                 Medium
# ..                                                 ...                    ...
# 195  Intense pain and bleeding from dental implant ...                    Low
# 196     Husband collapsed, not breathing, unresponsive                   High
# 197        Excruciating pain from lost dental filling.                    Low
# 198  Girlfriend's contraceptive shot wore off, worr...                    Low
# 199   Neighbor unresponsive, lacks pulse and breathing                   High
#
#     gpt-4-turbo - Clinician to Contact
# 0                              general
# 1                              general
# 2                              general
# 3                              general
# 4                              general
# ..                                 ...
# 195                            general
# 196                            general
# 197                            general
# 198                            general
# 199                            general
#
# [200 rows x 6 columns]

# %%
dfs.to_excel("gpt-4-turbo-shuffled_transcript-F200.xlsx")

# %%
# import pandas as pd
# from datetime import datetime
# import getpass

# def save_data(df,comments):
#     try:
#         current_datetime = datetime.now().strftime('%Y%m%d_%H%M%S')
#         username = getpass.getuser()
#         filename = f'{comments}_output{username}_{current_datetime}.xlsx'
#         df = pd.DataFrame(PROCESSED_DATA)
#         df.to_csv(filename, index=False)
#         print(f"DataFrame saved as {filename}")
#     except Exception as e:
#         print(f"An error occurred: {e}")

# %%
# save_data(dfs,"mixtral_8x7b")

# %%
# transcript_df_shuffled = transcript_df.sample(frac=1).reset_index(drop=True)
# transcript_df_shuffled.to_excel("transcript_shuffled.xlsx", index=False)
# transcript_df_shuffled
